# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, mean_absolute_percentage_error as mape
import numpy as np
# Batch size during training
import torch.optim as optim
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
import os
import warnings
warnings.filterwarnings("ignore")




def asmape(y_true, y_pred, mask=None):
    if mask is not None:
         y_true, y_pred = y_true[mask==1], y_pred[mask==1]
    if type(y_true) is list or type(y_pred) is list:
         y_true, y_pred = np.array(y_true), np.array(y_pred)
    len_ = len(y_true)
    tmp = 100 * (np.nansum(np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))/len_)

    return tmp


class LoaderDataset(Dataset):
    def __init__(self, root_zebra, root_horse, root_masks, chanels=3):
        self.root_zebra = root_zebra
        self.root_horse = root_horse
        self.root_index = root_masks
        
        self.zebra_images = sorted(os.listdir(root_zebra))
        self.horse_images = sorted(os.listdir(root_horse))
        self.index = sorted(os.listdir(root_masks))

        self.length_dataset = max(len(self.zebra_images), len(self.horse_images))
        self.zebra_len = len(self.zebra_images)
        self.horse_len = len(self.horse_images)
        self.index_len = len(self.index)
        self.chanels = chanels

    def __len__(self):
        return self.length_dataset

    @staticmethod
    def custom_normalize(image):
        image = torch.tensor(image, dtype=torch.float32)
        min_val = torch.min(image)
        max_val = torch.max(image)
        scale = torch.clamp(max_val - min_val, min=1e-5)  # Evita divisão por zero
        image_normalized = 2 * (image - min_val) / scale - 1  # Escala para [-1, 1]
        return image_normalized, min_val, max_val

    def __getitem__(self, index):
        zebra_img = self.zebra_images[index % self.zebra_len]
        horse_img = self.horse_images[index % self.horse_len]
        index_ids = self.index[index % self.index_len]

        zebra_path = os.path.join(self.root_zebra, zebra_img)
        horse_path = os.path.join(self.root_horse, horse_img)
        index_path = os.path.join(self.root_index, index_ids)
        # print(zebra_path, horse_path, index_path)

        zebra_img = np.load(zebra_path)
        horse_img = np.load(horse_path)
        mask = np.load(index_path)

        if len(zebra_img.shape) > 3:
            zebra_img = zebra_img.reshape(32, 32, 3)
            horse_img = horse_img.reshape(32, 32, 3)

        zebra_img = np.transpose(zebra_img, (2, 0, 1))
        horse_img = np.transpose(horse_img, (2, 0, 1))

        if self.chanels == 2:
            zebra_img = zebra_img[:2, :, :]
            horse_img = horse_img[:2, :, :]
        elif self.chanels == 1:
            zebra_img = np.sum(zebra_img, axis=0, keepdims=True)
            horse_img = np.sum(horse_img, axis=0, keepdims=True)

        zebra_img, min_val_z, max_val_z = LoaderDataset.custom_normalize(zebra_img)
        horse_img, _, _ = LoaderDataset.custom_normalize(horse_img)

        mask = torch.tensor(mask, dtype=torch.float32)

        return zebra_img, horse_img.flatten(), min_val_z, max_val_z, mask

# %%
class Generator(nn.Module):
    def __init__(self, nz=3072, ngf=32, nc=3):
        super(Generator, self).__init__()
        self.nz = nz
        self.ngf = ngf
        self.nc = nc

        self.main = nn.Sequential(
            # Camada Linear para mapear o vetor de entrada para um tamanho de 8x8xngf*8
            nn.Linear(self.nz, self.ngf * 8 * 8 * 8),
            nn.ReLU(True),

            # Redimensiona para (ngf*8) x 8 x 8
            nn.Unflatten(1, (self.ngf * 8, 8, 8)),

            # Convoluções transpostas para aumentar gradualmente a resolução
            nn.ConvTranspose2d(self.ngf * 8, self.ngf * 4, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(self.ngf * 4),
            nn.ReLU(True),

            nn.ConvTranspose2d(self.ngf * 4, self.ngf * 2, kernel_size=4, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(self.ngf * 2),
            nn.ReLU(True),

            nn.ConvTranspose2d(self.ngf * 2, self.ngf, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(self.ngf),
            nn.ReLU(True),         
        
            # Ajuste final: reduzir a última camada para não aumentar o tamanho da imagem
            nn.ConvTranspose2d(self.ngf, self.nc, kernel_size=3, stride=1, padding=1, bias=False),
            nn.Tanh()  # Normaliza a saída entre [-1, 1]
        )

    def forward(self, input):
        return self.main(input)

# %%
class Discriminator(nn.Module):
    def __init__(self, nc=3, ndf=64):
        super(Discriminator, self).__init__()
    
        self.nc = nc
        self.ndf = ndf

        self.main = nn.Sequential(
            # Camada 1: Convolução com stride 2 reduz a imagem para (image_size/2) x (image_size/2)
            nn.Conv2d(self.nc, self.ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Camada 2: Convolução com stride 2 reduz a imagem para (image_size/4) x (image_size/4)
            nn.Conv2d(self.ndf, self.ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Camada 3: Convolução com stride 2 reduz a imagem para (image_size/8) x (image_size/8)
            nn.Conv2d(self.ndf * 2, self.ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Camada 4: Convolução com stride 2 reduz a imagem para (image_size/16) x (image_size/16)
            nn.Conv2d(self.ndf * 4, self.ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            
            # Camada final: Convolução com kernel de (2, 2) para reduzir a imagem para 1 x 1
            nn.Conv2d(self.ndf * 8, 1, 2, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)

# %%
def asmape(y_true, y_pred, mask=None):
    if mask is not None:
         y_true, y_pred = y_true[mask==1], y_pred[mask==1]
    if type(y_true) is list or type(y_pred) is list:
         y_true, y_pred = np.array(y_true), np.array(y_pred)
    len_ = len(y_true)
    tmp = 100 * (np.nansum(np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))/len_)

    return tmp



def add_masked_gaussian_noise(x: torch.Tensor, mask: torch.Tensor, sigma: float) -> torch.Tensor:
    # x: [B,C,H,W], mask: [B,1,H,W]
    inv = (1.0 - mask).expand(-1, x.size(1), -1, -1)
    noise = torch.randn_like(x) * sigma
    return x + inv * noise


def james_stein_reduce(losses: torch.Tensor, eps: float = 1e-8) -> torch.Tensor:
    """
    Applies the James-Stein estimator to the mean of a vector of individual losses.

    Args:
        losses (torch.Tensor): 1D tensor of individual losses.
        eps (float): Numerical stability term.

    Returns:
        torch.Tensor: Smoothed mean of losses using James-Stein.
    """
    n = losses.numel()
    mu = losses.mean()
    S2 = torch.var(losses, unbiased=False)
    norm_sq = torch.sum((losses - mu)**2)
    shrinkage = torch.clamp(1 - ((n-2) * S2 / (norm_sq + eps)), min=0.0)
    # Estimator of the James-Stein
    js_mean = mu + shrinkage * (losses - mu).mean()
    return js_mean

def add_masked_gaussian_noise_vector(x: torch.Tensor, mask: torch.Tensor, sigma: float = 0.1) -> torch.Tensor:
    """
    Applies masked Gaussian noise to vector x, where the mask must have the same vector dimension.
    The original mask (usually [B, 1, H, W]) must be flattened and projected to the same shape as x.
    """
    # x: [B, F]
    # mask: [B, 1, H, W] → needs to be transformed to [B, F]
    B, F = x.size()

    # Achatar máscara para [B, H*W]
    mask_flat = mask.view(mask.size(0), -1)  # [B, H*W]

    # Design for the same number of features as x
    if mask_flat.size(1) != F:
        # Interpolate or repeat to adjust (depending on the case)
        mask_flat = torch.nn.functional.interpolate(mask_flat.unsqueeze(1), size=F, mode="nearest").squeeze(1)

    # cresats noise
    noise = torch.randn_like(x) * sigma

    # Applies noise where the mask is 0
    inv = (1.0 - mask_flat)
    return x + inv * noise

def train_and_val(loader, val_loader, nc, num_epochs=50, patience=100, device=None):
    
    
    netG = Generator(nz=nc*1024, nc=nc).to(device)
    netD = Discriminator(nc=nc).to(device)

    lr = 1e-5
    beta1 = 0.5
    best_loss = np.inf
    patience_counter = 0

    optimizerD = optim.Adam(netD.parameters(), lr=lr, betas=(beta1, 0.999))
    optimizerG = optim.Adam(netG.parameters(), lr=lr, betas=(beta1, 0.999))
    criterion = nn.BCELoss(reduction="none")

    real_label = 1.
    fake_label = 0.

    print("Starting Training Loop...")

    for epoch in range(num_epochs):
        initial_sigma = 0.1
        warmup_epochs = 100
        sigma = max(0.0, initial_sigma * (1 - epoch / warmup_epochs))

        for i, (real, noise, _, _, masks) in enumerate(loader):
            noise = noise.to(device)
            real_gpu = real.to(device)
            masks = masks.to(device).view(-1, 1, 32, 32).float()

            real_noisy = add_masked_gaussian_noise(real_gpu, masks, sigma)
            noise_noisy = add_masked_gaussian_noise_vector(noise, masks, sigma)

            real_masked = real_noisy * masks

            ### train Discriminador ###
            netD.zero_grad()
            b_size = real_gpu.size(0)

            # Real
            label_real = torch.full((b_size,), real_label, device=device)
            output_real = netD(real_masked).view(-1)
            errD_real = james_stein_reduce(criterion(output_real, label_real))

            # Fake
            fake = netG(noise_noisy).detach()
            fake_masked = fake * masks
            label_fake = torch.full((b_size,), fake_label, device=device)
            output_fake = netD(fake_masked).view(-1)
            errD_fake = james_stein_reduce(criterion(output_fake, label_fake))

            errD = errD_real + errD_fake
            errD.backward()
            optimizerD.step()

            ### train Generator ###
            netG.zero_grad()
            label_real = torch.full((b_size,), real_label, device=device)
            outG = netG(noise_noisy)
            outG_masked = outG * masks
            outputG = netD(outG_masked).view(-1)
            errG = james_stein_reduce(criterion(outputG, label_real))
            errG.backward()
            optimizerG.step()

            if i % 100 == 0:
                print(f"[{epoch}/{num_epochs}][{i}/{len(loader)}] "
                      f"Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f}")

        # Validation with James-Stein
        avg_loss_G = validate(val_loader, netD=netD, netG=netG, device=device, criterion=criterion)

        if avg_loss_G < best_loss:
            best_loss = avg_loss_G
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f"Early stopping na época {epoch}!")
            break

    return netG


def validate(loader, netG, netD, device, criterion):
    netG.eval()
    netD.eval()

    total_loss_G = 0.0
    total_loss_D = 0.0
    num_batches = 0

    with torch.no_grad():
        for real_cpu, noise, _, _, masks in loader:
            real_cpu = real_cpu.to(device)
            noise = noise.to(device)
            masks = masks.to(device).view(-1, 1, 32, 32).float()
            noise = add_masked_gaussian_noise_vector(noise, masks, sigma=0.1)
            real_cpu = add_masked_gaussian_noise(real_cpu, masks, sigma=0.1)

            real_masked = real_cpu * masks
            fake = netG(noise)
            fake_masked = fake * masks

            output_real = netD(real_masked).view(-1)
            output_fake = netD(fake_masked).view(-1)

            label_real = torch.full_like(output_real, 1.0, device=device)
            label_fake = torch.full_like(output_fake, 0.0, device=device)

            loss_real = criterion(output_real, label_real)
            loss_fake = criterion(output_fake, label_fake)
            loss_D = james_stein_reduce(loss_real) + james_stein_reduce(loss_fake)
            loss_G = james_stein_reduce(criterion(output_fake, label_real))

            total_loss_D += loss_D.item()
            total_loss_G += loss_G.item()
            num_batches += 1

    avg_loss_D = total_loss_D / num_batches
    avg_loss_G = total_loss_G / num_batches
    print(f'Validation Loss_D: {avg_loss_D:.4f} \tValidation Loss_G: {avg_loss_G:.4f}')

    netG.train()
    netD.train()
    return avg_loss_G



def discriminator_loss(real_output, fake_output):
    criterion = nn.BCEWithLogitsLoss()
    real_loss = criterion(real_output, torch.ones_like(real_output, device=real_output.device))
    fake_loss = criterion(fake_output, torch.zeros_like(fake_output, device=fake_output.device))
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    criterion = nn.BCEWithLogitsLoss()
    return criterion(fake_output, torch.ones_like(fake_output, device=fake_output.device))


def test( gen, test_loader, taxa, fold, chanells, device):  
    gen.eval()

  
    with torch.no_grad():
        df = pd.DataFrame([],columns=['mae','asmape','mape','rmse','scale'], index=test_loader.dataset.horse_images)
        for (zebra, horse,std_val,mean_val, masks), name in zip(test_loader,test_loader.dataset.horse_images):
        
            zebra = zebra.to(device)
            horse = horse.to(device)
           
            # Converter k e min_val para tensores, mas movê-los para GPU somente se necessário
            std_val = torch.tensor(std_val) if not isinstance(std_val, torch.Tensor) else std_val
            mean_val = torch.tensor(mean_val) if not isinstance(mean_val, torch.Tensor) else mean_val
            
            # Gerar fake_zebra usando o gerador
            fake_zebra = gen(horse)
         
            # Mover apenas as imagens para CPU antes de operações subsequentes
            zebra = zebra.cpu()
            fake_zebra = fake_zebra.cpu()
            
             #Voltar para escala original 
            zebra = (zebra)*std_val + mean_val
            fake_zebra = (fake_zebra)* std_val + mean_val

             # Somar sobre o canal e achatar as imagens
            zebra = torch.sum(zebra, dim=1).flatten()
            fake_zebra = torch.sum(fake_zebra, dim=1).flatten()

            # Calcular as métricas
            zebra_np = zebra*masks
            fake_zebra_np = fake_zebra*masks

				    # Calcular as métricas corretamente
            mae_value = round(mae(zebra_np, fake_zebra_np), 3)
            mape_value = round(mape(zebra_np, fake_zebra_np) * 100, 3)
            rmse_value = round(np.sqrt(mse(zebra_np, fake_zebra_np)), 3)
            smape_value = round(asmape(zebra_np, fake_zebra_np,masks), 3)
            # Adicionar os resultados ao DataFram
            df.loc[name] = [mae_value, smape_value, mape_value, rmse_value, np.max(zebra.numpy()) - np.min(zebra.numpy())]

				# Salva o DataFrame em um arquivo CSV
        directory =  "./resultados/resultados_dc"
        if not os.path.exists(directory):
          os.makedirs(directory)
        df.to_csv(rf'{directory}/result_{str(chanells)}c_{taxa}_{fold}.csv')

# %%
TRAIN_DIR = os.path.abspath("../dataset_final")  
VAL_DIR = os.path.abspath("../dataset_final")  
INDEX_TRAIN = os.path.abspath("../dataset_final")  
INDEX_VAL = os.path.abspath("../dataset_final")  
INDEX_TEST = os.path.abspath("../dataset_final")

# %%
BATCH_SIZE = 1000
NUM_EPOCHS =50000
 
           
def main(in_channels):
    device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
    for taxa in ['10','20','30','40']:
        for fold in ['1','2','3','4','5']:  
        
            dataset = LoaderDataset(
                  root_zebra=os.path.join( TRAIN_DIR, "label", str(taxa), "folds", f"fold{fold}", "train"),
                  root_horse=os.path.join( TRAIN_DIR, "input", str(taxa), "folds", f"fold{fold}", "train"),
									root_masks=os.path.join( INDEX_TRAIN, "input", str(taxa), "folds", f"fold{fold}", "index_train"),
									chanels=in_channels
							  )
                
            val_dataset = LoaderDataset(
                root_zebra=os.path.join( VAL_DIR, "label", str(taxa), "folds", f"fold{fold}", "val"),
								root_horse=os.path.join( VAL_DIR, "input", str(taxa), "folds", f"fold{fold}", "val"),
								root_masks=os.path.join( INDEX_VAL, "input", str(taxa), "folds", f"fold{fold}", "index_val"),
								chanels=in_channels
						  )

            test_dataset = LoaderDataset(
                  root_zebra=os.path.join( VAL_DIR, "label", str(taxa), "folds", f"fold{fold}", "test"),
									root_horse=os.path.join( VAL_DIR, "input", str(taxa), "folds", f"fold{fold}", "test"),
									root_masks=os.path.join(INDEX_TEST, "input", str(taxa), "folds", f"fold{fold}", "index"),
									chanels=in_channels
						)
            			
            val_loader = DataLoader(
                val_dataset,
                batch_size=BATCH_SIZE,
                shuffle=False,
                pin_memory=False)
            
            loader = DataLoader(
                dataset,
                batch_size=BATCH_SIZE,
                shuffle=True,
           
                pin_memory=False)
            
            test_loader = DataLoader(
                    test_dataset,
                    batch_size=1,
                    shuffle=False,
                    pin_memory=False )
            
            #Treino        
            generator = train_and_val(loader, val_loader, nc=in_channels, num_epochs=NUM_EPOCHS,device=device)
            
            save_dir = f"./models_saved/dcgan/{in_channels}/{taxa}/fold{fold}"
            if not os.path.exists(save_dir):
                os.makedirs(save_dir)
                
            # Salvar modelo
            model_path = os.path.join(save_dir, "generator.pth")
            torch.save(generator.state_dict(), model_path)
            print(f"Modelo salvo em: {model_path}")

            # Teste
            print('Iniciando o teste ....')
            test(generator,test_loader=test_loader,taxa=taxa,fold=fold,chanells=in_channels, device=device)

import time

# import torch.multiprocessing as mp

if __name__ == '__main__':
    start_time = time.time()
  # Necessário no Windows para compatibilidade
    for i in [1,2,3]:
        main(i)
    total_time = time.time() - start_time
    print(f'{total_time/3600} hours')
# Out:
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.4338 Loss_G: 0.6915
# Validation Loss_D: 1.3879 	Validation Loss_G: 0.6521
# [1/1000][0/2] Loss_D: 1.4283 Loss_G: 0.7010
# Validation Loss_D: 1.3911 	Validation Loss_G: 0.6194
# [2/1000][0/2] Loss_D: 1.4240 Loss_G: 0.7203
# Validation Loss_D: 1.3957 	Validation Loss_G: 0.5966
# [3/1000][0/2] Loss_D: 1.4229 Loss_G: 0.7262
# Validation Loss_D: 1.4017 	Validation Loss_G: 0.5754
# [4/1000][0/2] Loss_D: 1.4198 Loss_G: 0.7254
# Validation Loss_D: 1.4050 	Validation Loss_G: 0.5665
# [5/1000][0/2] Loss_D: 1.4113 Loss_G: 0.7235
# Validation Loss_D: 1.4119 	Validation Loss_G: 0.5587
# [6/1000][0/2] Loss_D: 1.4117 Loss_G: 0.7189
# Validation Loss_D: 1.4119 	Validation Loss_G: 0.5704
# [7/1000][0/2] Loss_D: 1.4081 Loss_G: 0.7182
# Validation Loss_D: 1.4027 	Validation Loss_G: 0.5959
# [8/1000][0/2] Loss_D: 1.4050 Loss_G: 0.7137
# Validation Loss_D: 1.3851 	Validation Loss_G: 0.6317
# [9/1000][0/2] Loss_D: 1.4006 Loss_G: 0.7161
# Validation Loss_D: 1.3720 	Validation Loss_G: 0.6704
# [10/1000][0/2] Loss_D: 1.3978 Loss_G: 0.7166
# Validation Loss_D: 1.3705 	Validation Loss_G: 0.6887
# [11/1000][0/2] Loss_D: 1.3933 Loss_G: 0.7244
# Validation Loss_D: 1.3603 	Validation Loss_G: 0.7247
# [12/1000][0/2] Loss_D: 1.3872 Loss_G: 0.7300
# Validation Loss_D: 1.3549 	Validation Loss_G: 0.7471
# [13/1000][0/2] Loss_D: 1.3848 Loss_G: 0.7308
# Validation Loss_D: 1.3549 	Validation Loss_G: 0.7643
# [14/1000][0/2] Loss_D: 1.3807 Loss_G: 0.7336
# Validation Loss_D: 1.3533 	Validation Loss_G: 0.7733
# [15/1000][0/2] Loss_D: 1.3801 Loss_G: 0.7322
# Validation Loss_D: 1.3428 	Validation Loss_G: 0.7848
# [16/1000][0/2] Loss_D: 1.3734 Loss_G: 0.7383
# Validation Loss_D: 1.3456 	Validation Loss_G: 0.7794
# [17/1000][0/2] Loss_D: 1.3730 Loss_G: 0.7319
# Validation Loss_D: 1.3408 	Validation Loss_G: 0.7803
# [18/1000][0/2] Loss_D: 1.3736 Loss_G: 0.7312
# Validation Loss_D: 1.3424 	Validation Loss_G: 0.7730
# [19/1000][0/2] Loss_D: 1.3683 Loss_G: 0.7281
# Validation Loss_D: 1.3351 	Validation Loss_G: 0.7796
# [20/1000][0/2] Loss_D: 1.3637 Loss_G: 0.7308
# Validation Loss_D: 1.3308 	Validation Loss_G: 0.7869
# [21/1000][0/2] Loss_D: 1.3617 Loss_G: 0.7370
# Validation Loss_D: 1.3284 	Validation Loss_G: 0.7977
# [22/1000][0/2] Loss_D: 1.3576 Loss_G: 0.7439
# Validation Loss_D: 1.3233 	Validation Loss_G: 0.8119
# [23/1000][0/2] Loss_D: 1.3541 Loss_G: 0.7458
# Validation Loss_D: 1.3244 	Validation Loss_G: 0.8067
# [24/1000][0/2] Loss_D: 1.3548 Loss_G: 0.7438
# Validation Loss_D: 1.3231 	Validation Loss_G: 0.8155
# [25/1000][0/2] Loss_D: 1.3530 Loss_G: 0.7451
# Validation Loss_D: 1.3250 	Validation Loss_G: 0.8101
# [26/1000][0/2] Loss_D: 1.3509 Loss_G: 0.7475
# Validation Loss_D: 1.3262 	Validation Loss_G: 0.8094
# [27/1000][0/2] Loss_D: 1.3496 Loss_G: 0.7491
# Validation Loss_D: 1.3212 	Validation Loss_G: 0.8109
# [28/1000][0/2] Loss_D: 1.3495 Loss_G: 0.7450
# Validation Loss_D: 1.3193 	Validation Loss_G: 0.8144
# [29/1000][0/2] Loss_D: 1.3526 Loss_G: 0.7448
# Validation Loss_D: 1.3266 	Validation Loss_G: 0.8101
# [30/1000][0/2] Loss_D: 1.3466 Loss_G: 0.7484
# Validation Loss_D: 1.3202 	Validation Loss_G: 0.8260
# [31/1000][0/2] Loss_D: 1.3466 Loss_G: 0.7489
# Validation Loss_D: 1.3237 	Validation Loss_G: 0.8293
# [32/1000][0/2] Loss_D: 1.3495 Loss_G: 0.7487
# Validation Loss_D: 1.3235 	Validation Loss_G: 0.8316
# [33/1000][0/2] Loss_D: 1.3493 Loss_G: 0.7582
# Validation Loss_D: 1.3168 	Validation Loss_G: 0.8422
# [34/1000][0/2] Loss_D: 1.3445 Loss_G: 0.7550
# Validation Loss_D: 1.3275 	Validation Loss_G: 0.8310
# [35/1000][0/2] Loss_D: 1.3462 Loss_G: 0.7523
# Validation Loss_D: 1.3202 	Validation Loss_G: 0.8337
# [36/1000][0/2] Loss_D: 1.3445 Loss_G: 0.7573
# Validation Loss_D: 1.3153 	Validation Loss_G: 0.8307
# [37/1000][0/2] Loss_D: 1.3458 Loss_G: 0.7499
# Validation Loss_D: 1.3195 	Validation Loss_G: 0.8218
# [38/1000][0/2] Loss_D: 1.3430 Loss_G: 0.7512
# Validation Loss_D: 1.3157 	Validation Loss_G: 0.8339
# [39/1000][0/2] Loss_D: 1.3401 Loss_G: 0.7602
# Validation Loss_D: 1.3143 	Validation Loss_G: 0.8378
# [40/1000][0/2] Loss_D: 1.3433 Loss_G: 0.7577
# Validation Loss_D: 1.3081 	Validation Loss_G: 0.8471
# [41/1000][0/2] Loss_D: 1.3414 Loss_G: 0.7504
# Validation Loss_D: 1.3101 	Validation Loss_G: 0.8524
# [42/1000][0/2] Loss_D: 1.3418 Loss_G: 0.7454
# Validation Loss_D: 1.3065 	Validation Loss_G: 0.8506
# [43/1000][0/2] Loss_D: 1.3412 Loss_G: 0.7442
# Validation Loss_D: 1.3091 	Validation Loss_G: 0.8437
# [44/1000][0/2] Loss_D: 1.3428 Loss_G: 0.7452
# Validation Loss_D: 1.3063 	Validation Loss_G: 0.8538
# [45/1000][0/2] Loss_D: 1.3389 Loss_G: 0.7501
# Validation Loss_D: 1.3109 	Validation Loss_G: 0.8501
# [46/1000][0/2] Loss_D: 1.3412 Loss_G: 0.7454
# Validation Loss_D: 1.3047 	Validation Loss_G: 0.8528
# [47/1000][0/2] Loss_D: 1.3387 Loss_G: 0.7567
# Validation Loss_D: 1.3044 	Validation Loss_G: 0.8591
# [48/1000][0/2] Loss_D: 1.3352 Loss_G: 0.7623
# Validation Loss_D: 1.3005 	Validation Loss_G: 0.8716
# [49/1000][0/2] Loss_D: 1.3369 Loss_G: 0.7639
# Validation Loss_D: 1.2943 	Validation Loss_G: 0.8748
# [50/1000][0/2] Loss_D: 1.3380 Loss_G: 0.7613
# Validation Loss_D: 1.2963 	Validation Loss_G: 0.8594
# [51/1000][0/2] Loss_D: 1.3340 Loss_G: 0.7541
# Validation Loss_D: 1.2977 	Validation Loss_G: 0.8624
# [52/1000][0/2] Loss_D: 1.3321 Loss_G: 0.7548
# Validation Loss_D: 1.2915 	Validation Loss_G: 0.8666
# [53/1000][0/2] Loss_D: 1.3331 Loss_G: 0.7549
# Validation Loss_D: 1.2931 	Validation Loss_G: 0.8643
# [54/1000][0/2] Loss_D: 1.3302 Loss_G: 0.7493
# Validation Loss_D: 1.2931 	Validation Loss_G: 0.8600
# [55/1000][0/2] Loss_D: 1.3297 Loss_G: 0.7476
# Validation Loss_D: 1.2980 	Validation Loss_G: 0.8623
# [56/1000][0/2] Loss_D: 1.3274 Loss_G: 0.7548
# Validation Loss_D: 1.3020 	Validation Loss_G: 0.8642
# [57/1000][0/2] Loss_D: 1.3246 Loss_G: 0.7588
# Validation Loss_D: 1.2845 	Validation Loss_G: 0.8892
# [58/1000][0/2] Loss_D: 1.3241 Loss_G: 0.7607
# Validation Loss_D: 1.2887 	Validation Loss_G: 0.8853
# [59/1000][0/2] Loss_D: 1.3247 Loss_G: 0.7650
# Validation Loss_D: 1.2883 	Validation Loss_G: 0.9026
# [60/1000][0/2] Loss_D: 1.3243 Loss_G: 0.7712
# Validation Loss_D: 1.2787 	Validation Loss_G: 0.9183
# [61/1000][0/2] Loss_D: 1.3244 Loss_G: 0.7742
# Validation Loss_D: 1.2861 	Validation Loss_G: 0.9182
# [62/1000][0/2] Loss_D: 1.3237 Loss_G: 0.7812
# Validation Loss_D: 1.2792 	Validation Loss_G: 0.9247
# [63/1000][0/2] Loss_D: 1.3227 Loss_G: 0.7732
# Validation Loss_D: 1.2853 	Validation Loss_G: 0.9066
# [64/1000][0/2] Loss_D: 1.3212 Loss_G: 0.7686
# Validation Loss_D: 1.2842 	Validation Loss_G: 0.8869
# [65/1000][0/2] Loss_D: 1.3207 Loss_G: 0.7525
# Validation Loss_D: 1.2926 	Validation Loss_G: 0.8734
# [66/1000][0/2] Loss_D: 1.3214 Loss_G: 0.7527
# Validation Loss_D: 1.2863 	Validation Loss_G: 0.8855
# [67/1000][0/2] Loss_D: 1.3199 Loss_G: 0.7607
# Validation Loss_D: 1.2860 	Validation Loss_G: 0.8991
# [68/1000][0/2] Loss_D: 1.3201 Loss_G: 0.7579
# Validation Loss_D: 1.2814 	Validation Loss_G: 0.9010
# [69/1000][0/2] Loss_D: 1.3193 Loss_G: 0.7554
# Validation Loss_D: 1.2816 	Validation Loss_G: 0.8958
# [70/1000][0/2] Loss_D: 1.3220 Loss_G: 0.7521
# Validation Loss_D: 1.2802 	Validation Loss_G: 0.9059
# [71/1000][0/2] Loss_D: 1.3195 Loss_G: 0.7628
# Validation Loss_D: 1.2840 	Validation Loss_G: 0.9111
# [72/1000][0/2] Loss_D: 1.3198 Loss_G: 0.7623
# Validation Loss_D: 1.2831 	Validation Loss_G: 0.9150
# [73/1000][0/2] Loss_D: 1.3223 Loss_G: 0.7575
# Validation Loss_D: 1.2857 	Validation Loss_G: 0.9133
# [74/1000][0/2] Loss_D: 1.3222 Loss_G: 0.7594
# Validation Loss_D: 1.2881 	Validation Loss_G: 0.9008
# [75/1000][0/2] Loss_D: 1.3200 Loss_G: 0.7551
# Validation Loss_D: 1.2810 	Validation Loss_G: 0.9079
# [76/1000][0/2] Loss_D: 1.3228 Loss_G: 0.7452
# Validation Loss_D: 1.2905 	Validation Loss_G: 0.8984
# [77/1000][0/2] Loss_D: 1.3218 Loss_G: 0.7459
# Validation Loss_D: 1.2884 	Validation Loss_G: 0.9040
# [78/1000][0/2] Loss_D: 1.3237 Loss_G: 0.7466
# Validation Loss_D: 1.2865 	Validation Loss_G: 0.9237
# [79/1000][0/2] Loss_D: 1.3219 Loss_G: 0.7564
# Validation Loss_D: 1.2766 	Validation Loss_G: 0.9449
# [80/1000][0/2] Loss_D: 1.3225 Loss_G: 0.7561
# Validation Loss_D: 1.2776 	Validation Loss_G: 0.9427
# [81/1000][0/2] Loss_D: 1.3242 Loss_G: 0.7447
# Validation Loss_D: 1.2807 	Validation Loss_G: 0.9324
# [82/1000][0/2] Loss_D: 1.3236 Loss_G: 0.7439
# Validation Loss_D: 1.2778 	Validation Loss_G: 0.9299
# [83/1000][0/2] Loss_D: 1.3228 Loss_G: 0.7569
# Validation Loss_D: 1.2755 	Validation Loss_G: 0.9464
# [84/1000][0/2] Loss_D: 1.3243 Loss_G: 0.7618
# Validation Loss_D: 1.2771 	Validation Loss_G: 0.9553
# [85/1000][0/2] Loss_D: 1.3234 Loss_G: 0.7636
# Validation Loss_D: 1.2800 	Validation Loss_G: 0.9540
# [86/1000][0/2] Loss_D: 1.3224 Loss_G: 0.7652
# Validation Loss_D: 1.2737 	Validation Loss_G: 0.9586
# [87/1000][0/2] Loss_D: 1.3238 Loss_G: 0.7585
# Validation Loss_D: 1.2695 	Validation Loss_G: 0.9581
# [88/1000][0/2] Loss_D: 1.3223 Loss_G: 0.7600
# Validation Loss_D: 1.2667 	Validation Loss_G: 0.9592
# [89/1000][0/2] Loss_D: 1.3227 Loss_G: 0.7515
# Validation Loss_D: 1.2722 	Validation Loss_G: 0.9418
# [90/1000][0/2] Loss_D: 1.3205 Loss_G: 0.7499
# Validation Loss_D: 1.2767 	Validation Loss_G: 0.9431
# [91/1000][0/2] Loss_D: 1.3200 Loss_G: 0.7569
# Validation Loss_D: 1.2667 	Validation Loss_G: 0.9688
# [92/1000][0/2] Loss_D: 1.3159 Loss_G: 0.7624
# Validation Loss_D: 1.2730 	Validation Loss_G: 0.9573
# [93/1000][0/2] Loss_D: 1.3172 Loss_G: 0.7656
# Validation Loss_D: 1.2680 	Validation Loss_G: 0.9819
# [94/1000][0/2] Loss_D: 1.3177 Loss_G: 0.7671
# Validation Loss_D: 1.2621 	Validation Loss_G: 0.9862
# [95/1000][0/2] Loss_D: 1.3170 Loss_G: 0.7624
# Validation Loss_D: 1.2632 	Validation Loss_G: 0.9723
# [96/1000][0/2] Loss_D: 1.3166 Loss_G: 0.7524
# Validation Loss_D: 1.2692 	Validation Loss_G: 0.9702
# [97/1000][0/2] Loss_D: 1.3149 Loss_G: 0.7536
# Validation Loss_D: 1.2598 	Validation Loss_G: 0.9914
# [98/1000][0/2] Loss_D: 1.3143 Loss_G: 0.7610
# Validation Loss_D: 1.2589 	Validation Loss_G: 0.9915
# [99/1000][0/2] Loss_D: 1.3124 Loss_G: 0.7573
# Validation Loss_D: 1.2490 	Validation Loss_G: 0.9965
# [100/1000][0/2] Loss_D: 1.3113 Loss_G: 0.7642
# Validation Loss_D: 1.2564 	Validation Loss_G: 0.9827
# [101/1000][0/2] Loss_D: 1.3101 Loss_G: 0.7627
# Validation Loss_D: 1.2544 	Validation Loss_G: 0.9921
# [102/1000][0/2] Loss_D: 1.3080 Loss_G: 0.7601
# Validation Loss_D: 1.2553 	Validation Loss_G: 0.9877
# [103/1000][0/2] Loss_D: 1.3059 Loss_G: 0.7642
# Validation Loss_D: 1.2513 	Validation Loss_G: 0.9950
# [104/1000][0/2] Loss_D: 1.3037 Loss_G: 0.7670
# Validation Loss_D: 1.2551 	Validation Loss_G: 0.9880
# [105/1000][0/2] Loss_D: 1.3017 Loss_G: 0.7700
# Validation Loss_D: 1.2496 	Validation Loss_G: 1.0042
# Early stopping na época 105!
# Modelo salvo em: ./models_saved/dcgan/1/10/fold1/generator.pth
# Iniciando o teste ....
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.4163 Loss_G: 0.7302
# Validation Loss_D: 1.3870 	Validation Loss_G: 0.6716
# [1/1000][0/2] Loss_D: 1.4177 Loss_G: 0.7242
# Validation Loss_D: 1.3885 	Validation Loss_G: 0.6556
# [2/1000][0/2] Loss_D: 1.4158 Loss_G: 0.7290
# Validation Loss_D: 1.3902 	Validation Loss_G: 0.6457
# [3/1000][0/2] Loss_D: 1.4116 Loss_G: 0.7263
# Validation Loss_D: 1.3913 	Validation Loss_G: 0.6455
# [4/1000][0/2] Loss_D: 1.4078 Loss_G: 0.7275
# Validation Loss_D: 1.3927 	Validation Loss_G: 0.6445
# [5/1000][0/2] Loss_D: 1.4014 Loss_G: 0.7246
# Validation Loss_D: 1.3946 	Validation Loss_G: 0.6477
# [6/1000][0/2] Loss_D: 1.3992 Loss_G: 0.7254
# Validation Loss_D: 1.3964 	Validation Loss_G: 0.6635
# [7/1000][0/2] Loss_D: 1.3953 Loss_G: 0.7243
# Validation Loss_D: 1.4004 	Validation Loss_G: 0.6754
# [8/1000][0/2] Loss_D: 1.3928 Loss_G: 0.7271
# Validation Loss_D: 1.4020 	Validation Loss_G: 0.6869
# [9/1000][0/2] Loss_D: 1.3877 Loss_G: 0.7314
# Validation Loss_D: 1.4022 	Validation Loss_G: 0.7022
# [10/1000][0/2] Loss_D: 1.3853 Loss_G: 0.7339
# Validation Loss_D: 1.4031 	Validation Loss_G: 0.7161
# [11/1000][0/2] Loss_D: 1.3808 Loss_G: 0.7390
# Validation Loss_D: 1.4027 	Validation Loss_G: 0.7247
# [12/1000][0/2] Loss_D: 1.3771 Loss_G: 0.7393
# Validation Loss_D: 1.3979 	Validation Loss_G: 0.7396
# [13/1000][0/2] Loss_D: 1.3750 Loss_G: 0.7430
# Validation Loss_D: 1.3949 	Validation Loss_G: 0.7568
# [14/1000][0/2] Loss_D: 1.3725 Loss_G: 0.7477
# Validation Loss_D: 1.3876 	Validation Loss_G: 0.7667
# [15/1000][0/2] Loss_D: 1.3689 Loss_G: 0.7510
# Validation Loss_D: 1.3833 	Validation Loss_G: 0.7728
# [16/1000][0/2] Loss_D: 1.3653 Loss_G: 0.7507
# Validation Loss_D: 1.3819 	Validation Loss_G: 0.7678
# [17/1000][0/2] Loss_D: 1.3619 Loss_G: 0.7483
# Validation Loss_D: 1.3836 	Validation Loss_G: 0.7698
# [18/1000][0/2] Loss_D: 1.3567 Loss_G: 0.7484
# Validation Loss_D: 1.3842 	Validation Loss_G: 0.7573
# [19/1000][0/2] Loss_D: 1.3543 Loss_G: 0.7411
# Validation Loss_D: 1.3893 	Validation Loss_G: 0.7559
# [20/1000][0/2] Loss_D: 1.3526 Loss_G: 0.7464
# Validation Loss_D: 1.3772 	Validation Loss_G: 0.7815
# [21/1000][0/2] Loss_D: 1.3474 Loss_G: 0.7603
# Validation Loss_D: 1.3629 	Validation Loss_G: 0.7984
# [22/1000][0/2] Loss_D: 1.3460 Loss_G: 0.7651
# Validation Loss_D: 1.3656 	Validation Loss_G: 0.8075
# [23/1000][0/2] Loss_D: 1.3428 Loss_G: 0.7670
# Validation Loss_D: 1.3603 	Validation Loss_G: 0.8053
# [24/1000][0/2] Loss_D: 1.3381 Loss_G: 0.7656
# Validation Loss_D: 1.3616 	Validation Loss_G: 0.7992
# [25/1000][0/2] Loss_D: 1.3335 Loss_G: 0.7618
# Validation Loss_D: 1.3649 	Validation Loss_G: 0.7877
# [26/1000][0/2] Loss_D: 1.3321 Loss_G: 0.7550
# Validation Loss_D: 1.3561 	Validation Loss_G: 0.8035
# [27/1000][0/2] Loss_D: 1.3264 Loss_G: 0.7627
# Validation Loss_D: 1.3566 	Validation Loss_G: 0.8106
# [28/1000][0/2] Loss_D: 1.3239 Loss_G: 0.7762
# Validation Loss_D: 1.3570 	Validation Loss_G: 0.8118
# [29/1000][0/2] Loss_D: 1.3196 Loss_G: 0.7804
# Validation Loss_D: 1.3501 	Validation Loss_G: 0.8224
# [30/1000][0/2] Loss_D: 1.3188 Loss_G: 0.7807
# Validation Loss_D: 1.3511 	Validation Loss_G: 0.8237
# [31/1000][0/2] Loss_D: 1.3158 Loss_G: 0.7767
# Validation Loss_D: 1.3514 	Validation Loss_G: 0.8211
# [32/1000][0/2] Loss_D: 1.3145 Loss_G: 0.7638
# Validation Loss_D: 1.3542 	Validation Loss_G: 0.8118
# [33/1000][0/2] Loss_D: 1.3133 Loss_G: 0.7622
# Validation Loss_D: 1.3453 	Validation Loss_G: 0.8231
# [34/1000][0/2] Loss_D: 1.3144 Loss_G: 0.7636
# Validation Loss_D: 1.3461 	Validation Loss_G: 0.8298
# [35/1000][0/2] Loss_D: 1.3131 Loss_G: 0.7679
# Validation Loss_D: 1.3445 	Validation Loss_G: 0.8421
# [36/1000][0/2] Loss_D: 1.3140 Loss_G: 0.7701
# Validation Loss_D: 1.3370 	Validation Loss_G: 0.8514
# [37/1000][0/2] Loss_D: 1.3116 Loss_G: 0.7777
# Validation Loss_D: 1.3424 	Validation Loss_G: 0.8422
# [38/1000][0/2] Loss_D: 1.3108 Loss_G: 0.7712
# Validation Loss_D: 1.3504 	Validation Loss_G: 0.8383
# [39/1000][0/2] Loss_D: 1.3103 Loss_G: 0.7710
# Validation Loss_D: 1.3441 	Validation Loss_G: 0.8390
# [40/1000][0/2] Loss_D: 1.3081 Loss_G: 0.7714
# Validation Loss_D: 1.3371 	Validation Loss_G: 0.8404
# [41/1000][0/2] Loss_D: 1.3098 Loss_G: 0.7717
# Validation Loss_D: 1.3370 	Validation Loss_G: 0.8427
# [42/1000][0/2] Loss_D: 1.3098 Loss_G: 0.7725
# Validation Loss_D: 1.3358 	Validation Loss_G: 0.8483
# [43/1000][0/2] Loss_D: 1.3076 Loss_G: 0.7725
# Validation Loss_D: 1.3275 	Validation Loss_G: 0.8677
# [44/1000][0/2] Loss_D: 1.3101 Loss_G: 0.7783
# Validation Loss_D: 1.3288 	Validation Loss_G: 0.8737
# [45/1000][0/2] Loss_D: 1.3032 Loss_G: 0.7918
# Validation Loss_D: 1.3288 	Validation Loss_G: 0.8780
# [46/1000][0/2] Loss_D: 1.3085 Loss_G: 0.7808
# Validation Loss_D: 1.3292 	Validation Loss_G: 0.8664
# [47/1000][0/2] Loss_D: 1.3061 Loss_G: 0.7721
# Validation Loss_D: 1.3354 	Validation Loss_G: 0.8573
# [48/1000][0/2] Loss_D: 1.3052 Loss_G: 0.7683
# Validation Loss_D: 1.3349 	Validation Loss_G: 0.8491
# [49/1000][0/2] Loss_D: 1.3055 Loss_G: 0.7614
# Validation Loss_D: 1.3355 	Validation Loss_G: 0.8466
# [50/1000][0/2] Loss_D: 1.3056 Loss_G: 0.7494
# Validation Loss_D: 1.3356 	Validation Loss_G: 0.8426
# [51/1000][0/2] Loss_D: 1.3060 Loss_G: 0.7455
# Validation Loss_D: 1.3386 	Validation Loss_G: 0.8546
# [52/1000][0/2] Loss_D: 1.3044 Loss_G: 0.7556
# Validation Loss_D: 1.3293 	Validation Loss_G: 0.8733
# [53/1000][0/2] Loss_D: 1.3041 Loss_G: 0.7609
# Validation Loss_D: 1.3288 	Validation Loss_G: 0.8826
# [54/1000][0/2] Loss_D: 1.3046 Loss_G: 0.7687
# Validation Loss_D: 1.3292 	Validation Loss_G: 0.8894
# [55/1000][0/2] Loss_D: 1.3070 Loss_G: 0.7711
# Validation Loss_D: 1.3211 	Validation Loss_G: 0.8958
# [56/1000][0/2] Loss_D: 1.3049 Loss_G: 0.7740
# Validation Loss_D: 1.3146 	Validation Loss_G: 0.8982
# [57/1000][0/2] Loss_D: 1.3048 Loss_G: 0.7664
# Validation Loss_D: 1.3204 	Validation Loss_G: 0.8856
# [58/1000][0/2] Loss_D: 1.3030 Loss_G: 0.7691
# Validation Loss_D: 1.3211 	Validation Loss_G: 0.8840
# [59/1000][0/2] Loss_D: 1.3033 Loss_G: 0.7629
# Validation Loss_D: 1.3239 	Validation Loss_G: 0.8843
# [60/1000][0/2] Loss_D: 1.3014 Loss_G: 0.7650
# Validation Loss_D: 1.3185 	Validation Loss_G: 0.8965
# [61/1000][0/2] Loss_D: 1.3018 Loss_G: 0.7733
# Validation Loss_D: 1.3171 	Validation Loss_G: 0.8948
# [62/1000][0/2] Loss_D: 1.3029 Loss_G: 0.7696
# Validation Loss_D: 1.3166 	Validation Loss_G: 0.9094
# [63/1000][0/2] Loss_D: 1.3022 Loss_G: 0.7801
# Validation Loss_D: 1.3077 	Validation Loss_G: 0.9203
# [64/1000][0/2] Loss_D: 1.2994 Loss_G: 0.7853
# Validation Loss_D: 1.3029 	Validation Loss_G: 0.9275
# [65/1000][0/2] Loss_D: 1.2974 Loss_G: 0.7835
# Validation Loss_D: 1.3003 	Validation Loss_G: 0.9201
# [66/1000][0/2] Loss_D: 1.2956 Loss_G: 0.7777
# Validation Loss_D: 1.2997 	Validation Loss_G: 0.9127
# [67/1000][0/2] Loss_D: 1.2954 Loss_G: 0.7691
# Validation Loss_D: 1.2983 	Validation Loss_G: 0.9007
# [68/1000][0/2] Loss_D: 1.2917 Loss_G: 0.7645
# Validation Loss_D: 1.2971 	Validation Loss_G: 0.9057
# [69/1000][0/2] Loss_D: 1.2930 Loss_G: 0.7705
# Validation Loss_D: 1.2923 	Validation Loss_G: 0.9116
# [70/1000][0/2] Loss_D: 1.2890 Loss_G: 0.7786
# Validation Loss_D: 1.2853 	Validation Loss_G: 0.9315
# [71/1000][0/2] Loss_D: 1.2864 Loss_G: 0.7889
# Validation Loss_D: 1.2813 	Validation Loss_G: 0.9412
# [72/1000][0/2] Loss_D: 1.2836 Loss_G: 0.7904
# Validation Loss_D: 1.2778 	Validation Loss_G: 0.9439
# [73/1000][0/2] Loss_D: 1.2850 Loss_G: 0.7874
# Validation Loss_D: 1.2773 	Validation Loss_G: 0.9412
# [74/1000][0/2] Loss_D: 1.2818 Loss_G: 0.7826
# Validation Loss_D: 1.2796 	Validation Loss_G: 0.9320
# [75/1000][0/2] Loss_D: 1.2817 Loss_G: 0.7774
# Validation Loss_D: 1.2808 	Validation Loss_G: 0.9287
# [76/1000][0/2] Loss_D: 1.2797 Loss_G: 0.7760
# Validation Loss_D: 1.2836 	Validation Loss_G: 0.9298
# [77/1000][0/2] Loss_D: 1.2789 Loss_G: 0.7746
# Validation Loss_D: 1.2823 	Validation Loss_G: 0.9271
# [78/1000][0/2] Loss_D: 1.2785 Loss_G: 0.7765
# Validation Loss_D: 1.2772 	Validation Loss_G: 0.9422
# [79/1000][0/2] Loss_D: 1.2761 Loss_G: 0.7823
# Validation Loss_D: 1.2778 	Validation Loss_G: 0.9545
# [80/1000][0/2] Loss_D: 1.2737 Loss_G: 0.7947
# Validation Loss_D: 1.2760 	Validation Loss_G: 0.9588
# [81/1000][0/2] Loss_D: 1.2716 Loss_G: 0.7972
# Validation Loss_D: 1.2697 	Validation Loss_G: 0.9716
# [82/1000][0/2] Loss_D: 1.2712 Loss_G: 0.7934
# Validation Loss_D: 1.2742 	Validation Loss_G: 0.9534
# [83/1000][0/2] Loss_D: 1.2745 Loss_G: 0.7851
# Validation Loss_D: 1.2724 	Validation Loss_G: 0.9640
# [84/1000][0/2] Loss_D: 1.2715 Loss_G: 0.7879
# Validation Loss_D: 1.2693 	Validation Loss_G: 0.9498
# [85/1000][0/2] Loss_D: 1.2702 Loss_G: 0.7771
# Validation Loss_D: 1.2715 	Validation Loss_G: 0.9414
# [86/1000][0/2] Loss_D: 1.2691 Loss_G: 0.7741
# Validation Loss_D: 1.2707 	Validation Loss_G: 0.9431
# [87/1000][0/2] Loss_D: 1.2667 Loss_G: 0.7824
# Validation Loss_D: 1.2749 	Validation Loss_G: 0.9430
# [88/1000][0/2] Loss_D: 1.2682 Loss_G: 0.7833
# Validation Loss_D: 1.2819 	Validation Loss_G: 0.9488
# [89/1000][0/2] Loss_D: 1.2678 Loss_G: 0.7914
# Validation Loss_D: 1.2758 	Validation Loss_G: 0.9649
# [90/1000][0/2] Loss_D: 1.2700 Loss_G: 0.7777
# Validation Loss_D: 1.2722 	Validation Loss_G: 0.9693
# [91/1000][0/2] Loss_D: 1.2682 Loss_G: 0.7866
# Validation Loss_D: 1.2733 	Validation Loss_G: 0.9878
# [92/1000][0/2] Loss_D: 1.2682 Loss_G: 0.7908
# Validation Loss_D: 1.2775 	Validation Loss_G: 0.9907
# [93/1000][0/2] Loss_D: 1.2690 Loss_G: 0.7862
# Validation Loss_D: 1.2794 	Validation Loss_G: 0.9876
# [94/1000][0/2] Loss_D: 1.2693 Loss_G: 0.7852
# Validation Loss_D: 1.2777 	Validation Loss_G: 0.9846
# [95/1000][0/2] Loss_D: 1.2712 Loss_G: 0.7788
# Validation Loss_D: 1.2763 	Validation Loss_G: 0.9864
# [96/1000][0/2] Loss_D: 1.2674 Loss_G: 0.7970
# Validation Loss_D: 1.2760 	Validation Loss_G: 1.0021
# [97/1000][0/2] Loss_D: 1.2690 Loss_G: 0.7938
# Validation Loss_D: 1.2750 	Validation Loss_G: 1.0088
# [98/1000][0/2] Loss_D: 1.2686 Loss_G: 0.7910
# Validation Loss_D: 1.2699 	Validation Loss_G: 1.0175
# [99/1000][0/2] Loss_D: 1.2685 Loss_G: 0.7948
# Validation Loss_D: 1.2661 	Validation Loss_G: 1.0097
# [100/1000][0/2] Loss_D: 1.2684 Loss_G: 0.7872
# Validation Loss_D: 1.2692 	Validation Loss_G: 1.0044
# [101/1000][0/2] Loss_D: 1.2641 Loss_G: 0.8034
# Validation Loss_D: 1.2642 	Validation Loss_G: 1.0190
# [102/1000][0/2] Loss_D: 1.2672 Loss_G: 0.7939
# Validation Loss_D: 1.2702 	Validation Loss_G: 1.0077
# [103/1000][0/2] Loss_D: 1.2630 Loss_G: 0.7810
# Validation Loss_D: 1.2692 	Validation Loss_G: 1.0029
# [104/1000][0/2] Loss_D: 1.2649 Loss_G: 0.7775
# Validation Loss_D: 1.2661 	Validation Loss_G: 0.9938
# Early stopping na época 104!
# Modelo salvo em: ./models_saved/dcgan/1/10/fold2/generator.pth
# Iniciando o teste ....
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.4180 Loss_G: 0.7467
# Validation Loss_D: 1.3869 	Validation Loss_G: 0.6786
# [1/1000][0/2] Loss_D: 1.4101 Loss_G: 0.7312
# Validation Loss_D: 1.3878 	Validation Loss_G: 0.6647
# [2/1000][0/2] Loss_D: 1.4057 Loss_G: 0.7380
# Validation Loss_D: 1.3909 	Validation Loss_G: 0.6461
# [3/1000][0/2] Loss_D: 1.4000 Loss_G: 0.7386
# Validation Loss_D: 1.3949 	Validation Loss_G: 0.6352
# [4/1000][0/2] Loss_D: 1.3918 Loss_G: 0.7475
# Validation Loss_D: 1.4010 	Validation Loss_G: 0.6235
# [5/1000][0/2] Loss_D: 1.3893 Loss_G: 0.7393
# Validation Loss_D: 1.4067 	Validation Loss_G: 0.6235
# [6/1000][0/2] Loss_D: 1.3864 Loss_G: 0.7288
# Validation Loss_D: 1.4072 	Validation Loss_G: 0.6325
# [7/1000][0/2] Loss_D: 1.3796 Loss_G: 0.7335
# Validation Loss_D: 1.4045 	Validation Loss_G: 0.6485
# [8/1000][0/2] Loss_D: 1.3770 Loss_G: 0.7327
# Validation Loss_D: 1.3984 	Validation Loss_G: 0.6751
# [9/1000][0/2] Loss_D: 1.3709 Loss_G: 0.7408
# Validation Loss_D: 1.3962 	Validation Loss_G: 0.6987
# [10/1000][0/2] Loss_D: 1.3677 Loss_G: 0.7493
# Validation Loss_D: 1.3916 	Validation Loss_G: 0.7251
# [11/1000][0/2] Loss_D: 1.3626 Loss_G: 0.7610
# Validation Loss_D: 1.3831 	Validation Loss_G: 0.7558
# [12/1000][0/2] Loss_D: 1.3593 Loss_G: 0.7633
# Validation Loss_D: 1.3725 	Validation Loss_G: 0.7743
# [13/1000][0/2] Loss_D: 1.3541 Loss_G: 0.7615
# Validation Loss_D: 1.3753 	Validation Loss_G: 0.7617
# [14/1000][0/2] Loss_D: 1.3493 Loss_G: 0.7606
# Validation Loss_D: 1.3736 	Validation Loss_G: 0.7644
# [15/1000][0/2] Loss_D: 1.3481 Loss_G: 0.7595
# Validation Loss_D: 1.3736 	Validation Loss_G: 0.7698
# [16/1000][0/2] Loss_D: 1.3436 Loss_G: 0.7616
# Validation Loss_D: 1.3767 	Validation Loss_G: 0.7802
# [17/1000][0/2] Loss_D: 1.3375 Loss_G: 0.7671
# Validation Loss_D: 1.3717 	Validation Loss_G: 0.7918
# [18/1000][0/2] Loss_D: 1.3299 Loss_G: 0.7718
# Validation Loss_D: 1.3593 	Validation Loss_G: 0.7952
# [19/1000][0/2] Loss_D: 1.3271 Loss_G: 0.7692
# Validation Loss_D: 1.3630 	Validation Loss_G: 0.7909
# [20/1000][0/2] Loss_D: 1.3273 Loss_G: 0.7609
# Validation Loss_D: 1.3660 	Validation Loss_G: 0.7843
# [21/1000][0/2] Loss_D: 1.3218 Loss_G: 0.7669
# Validation Loss_D: 1.3568 	Validation Loss_G: 0.7963
# [22/1000][0/2] Loss_D: 1.3192 Loss_G: 0.7781
# Validation Loss_D: 1.3511 	Validation Loss_G: 0.8095
# [23/1000][0/2] Loss_D: 1.3140 Loss_G: 0.7864
# Validation Loss_D: 1.3613 	Validation Loss_G: 0.8017
# [24/1000][0/2] Loss_D: 1.3110 Loss_G: 0.7801
# Validation Loss_D: 1.3642 	Validation Loss_G: 0.7943
# [25/1000][0/2] Loss_D: 1.3082 Loss_G: 0.7753
# Validation Loss_D: 1.3644 	Validation Loss_G: 0.8005
# [26/1000][0/2] Loss_D: 1.3024 Loss_G: 0.7902
# Validation Loss_D: 1.3495 	Validation Loss_G: 0.8290
# [27/1000][0/2] Loss_D: 1.2987 Loss_G: 0.8051
# Validation Loss_D: 1.3553 	Validation Loss_G: 0.8234
# [28/1000][0/2] Loss_D: 1.2964 Loss_G: 0.7989
# Validation Loss_D: 1.3555 	Validation Loss_G: 0.8234
# [29/1000][0/2] Loss_D: 1.2925 Loss_G: 0.8009
# Validation Loss_D: 1.3567 	Validation Loss_G: 0.8157
# [30/1000][0/2] Loss_D: 1.2864 Loss_G: 0.8011
# Validation Loss_D: 1.3571 	Validation Loss_G: 0.8085
# [31/1000][0/2] Loss_D: 1.2836 Loss_G: 0.8006
# Validation Loss_D: 1.3585 	Validation Loss_G: 0.8020
# [32/1000][0/2] Loss_D: 1.2798 Loss_G: 0.7976
# Validation Loss_D: 1.3595 	Validation Loss_G: 0.8060
# [33/1000][0/2] Loss_D: 1.2757 Loss_G: 0.8043
# Validation Loss_D: 1.3686 	Validation Loss_G: 0.8023
# [34/1000][0/2] Loss_D: 1.2749 Loss_G: 0.8013
# Validation Loss_D: 1.3608 	Validation Loss_G: 0.8144
# [35/1000][0/2] Loss_D: 1.2703 Loss_G: 0.8117
# Validation Loss_D: 1.3586 	Validation Loss_G: 0.8230
# [36/1000][0/2] Loss_D: 1.2669 Loss_G: 0.8084
# Validation Loss_D: 1.3601 	Validation Loss_G: 0.8193
# [37/1000][0/2] Loss_D: 1.2634 Loss_G: 0.8026
# Validation Loss_D: 1.3533 	Validation Loss_G: 0.8261
# [38/1000][0/2] Loss_D: 1.2609 Loss_G: 0.8059
# Validation Loss_D: 1.3524 	Validation Loss_G: 0.8305
# [39/1000][0/2] Loss_D: 1.2579 Loss_G: 0.8080
# Validation Loss_D: 1.3520 	Validation Loss_G: 0.8331
# [40/1000][0/2] Loss_D: 1.2557 Loss_G: 0.8022
# Validation Loss_D: 1.3554 	Validation Loss_G: 0.8231
# [41/1000][0/2] Loss_D: 1.2546 Loss_G: 0.7968
# Validation Loss_D: 1.3467 	Validation Loss_G: 0.8256
# [42/1000][0/2] Loss_D: 1.2520 Loss_G: 0.7973
# Validation Loss_D: 1.3490 	Validation Loss_G: 0.8162
# [43/1000][0/2] Loss_D: 1.2496 Loss_G: 0.8004
# Validation Loss_D: 1.3439 	Validation Loss_G: 0.8357
# [44/1000][0/2] Loss_D: 1.2489 Loss_G: 0.8080
# Validation Loss_D: 1.3421 	Validation Loss_G: 0.8370
# [45/1000][0/2] Loss_D: 1.2460 Loss_G: 0.8041
# Validation Loss_D: 1.3390 	Validation Loss_G: 0.8448
# [46/1000][0/2] Loss_D: 1.2430 Loss_G: 0.8153
# Validation Loss_D: 1.3352 	Validation Loss_G: 0.8508
# [47/1000][0/2] Loss_D: 1.2399 Loss_G: 0.8192
# Validation Loss_D: 1.3350 	Validation Loss_G: 0.8518
# [48/1000][0/2] Loss_D: 1.2391 Loss_G: 0.8162
# Validation Loss_D: 1.3450 	Validation Loss_G: 0.8435
# [49/1000][0/2] Loss_D: 1.2380 Loss_G: 0.8094
# Validation Loss_D: 1.3382 	Validation Loss_G: 0.8540
# [50/1000][0/2] Loss_D: 1.2330 Loss_G: 0.8221
# Validation Loss_D: 1.3349 	Validation Loss_G: 0.8515
# [51/1000][0/2] Loss_D: 1.2280 Loss_G: 0.8210
# Validation Loss_D: 1.3337 	Validation Loss_G: 0.8636
# [52/1000][0/2] Loss_D: 1.2254 Loss_G: 0.8271
# Validation Loss_D: 1.3300 	Validation Loss_G: 0.8718
# [53/1000][0/2] Loss_D: 1.2244 Loss_G: 0.8333
# Validation Loss_D: 1.3256 	Validation Loss_G: 0.8806
# [54/1000][0/2] Loss_D: 1.2209 Loss_G: 0.8268
# Validation Loss_D: 1.3331 	Validation Loss_G: 0.8572
# [55/1000][0/2] Loss_D: 1.2172 Loss_G: 0.8276
# Validation Loss_D: 1.3269 	Validation Loss_G: 0.8627
# [56/1000][0/2] Loss_D: 1.2136 Loss_G: 0.8284
# Validation Loss_D: 1.3194 	Validation Loss_G: 0.8754
# [57/1000][0/2] Loss_D: 1.2104 Loss_G: 0.8335
# Validation Loss_D: 1.3111 	Validation Loss_G: 0.8809
# [58/1000][0/2] Loss_D: 1.2063 Loss_G: 0.8320
# Validation Loss_D: 1.3104 	Validation Loss_G: 0.8875
# [59/1000][0/2] Loss_D: 1.2065 Loss_G: 0.8239
# Validation Loss_D: 1.3089 	Validation Loss_G: 0.8766
# [60/1000][0/2] Loss_D: 1.2013 Loss_G: 0.8279
# Validation Loss_D: 1.3181 	Validation Loss_G: 0.8538
# [61/1000][0/2] Loss_D: 1.1981 Loss_G: 0.8209
# Validation Loss_D: 1.3087 	Validation Loss_G: 0.8768
# [62/1000][0/2] Loss_D: 1.1946 Loss_G: 0.8286
# Validation Loss_D: 1.2992 	Validation Loss_G: 0.8893
# [63/1000][0/2] Loss_D: 1.1907 Loss_G: 0.8459
# Validation Loss_D: 1.2873 	Validation Loss_G: 0.9160
# [64/1000][0/2] Loss_D: 1.1852 Loss_G: 0.8657
# Validation Loss_D: 1.2818 	Validation Loss_G: 0.9251
# [65/1000][0/2] Loss_D: 1.1837 Loss_G: 0.8598
# Validation Loss_D: 1.2782 	Validation Loss_G: 0.9176
# [66/1000][0/2] Loss_D: 1.1805 Loss_G: 0.8542
# Validation Loss_D: 1.2822 	Validation Loss_G: 0.9087
# [67/1000][0/2] Loss_D: 1.1770 Loss_G: 0.8529
# Validation Loss_D: 1.2818 	Validation Loss_G: 0.9091
# [68/1000][0/2] Loss_D: 1.1739 Loss_G: 0.8586
# Validation Loss_D: 1.2757 	Validation Loss_G: 0.9213
# [69/1000][0/2] Loss_D: 1.1713 Loss_G: 0.8619
# Validation Loss_D: 1.2622 	Validation Loss_G: 0.9339
# [70/1000][0/2] Loss_D: 1.1680 Loss_G: 0.8591
# Validation Loss_D: 1.2555 	Validation Loss_G: 0.9334
# [71/1000][0/2] Loss_D: 1.1678 Loss_G: 0.8504
# Validation Loss_D: 1.2509 	Validation Loss_G: 0.9251
# [72/1000][0/2] Loss_D: 1.1671 Loss_G: 0.8510
# Validation Loss_D: 1.2434 	Validation Loss_G: 0.9275
# [73/1000][0/2] Loss_D: 1.1620 Loss_G: 0.8613
# Validation Loss_D: 1.2428 	Validation Loss_G: 0.9305
# [74/1000][0/2] Loss_D: 1.1608 Loss_G: 0.8747
# Validation Loss_D: 1.2417 	Validation Loss_G: 0.9438
# [75/1000][0/2] Loss_D: 1.1558 Loss_G: 0.8957
# Validation Loss_D: 1.2345 	Validation Loss_G: 0.9678
# [76/1000][0/2] Loss_D: 1.1560 Loss_G: 0.8898
# Validation Loss_D: 1.2375 	Validation Loss_G: 0.9577
# [77/1000][0/2] Loss_D: 1.1514 Loss_G: 0.8832
# Validation Loss_D: 1.2352 	Validation Loss_G: 0.9660
# [78/1000][0/2] Loss_D: 1.1492 Loss_G: 0.8737
# Validation Loss_D: 1.2368 	Validation Loss_G: 0.9536
# [79/1000][0/2] Loss_D: 1.1491 Loss_G: 0.8730
# Validation Loss_D: 1.2268 	Validation Loss_G: 0.9728
# [80/1000][0/2] Loss_D: 1.1449 Loss_G: 0.8979
# Validation Loss_D: 1.2167 	Validation Loss_G: 1.0119
# [81/1000][0/2] Loss_D: 1.1442 Loss_G: 0.9098
# Validation Loss_D: 1.2158 	Validation Loss_G: 1.0110
# [82/1000][0/2] Loss_D: 1.1403 Loss_G: 0.9030
# Validation Loss_D: 1.2170 	Validation Loss_G: 0.9952
# [83/1000][0/2] Loss_D: 1.1361 Loss_G: 0.8918
# Validation Loss_D: 1.2233 	Validation Loss_G: 0.9677
# [84/1000][0/2] Loss_D: 1.1334 Loss_G: 0.8823
# Validation Loss_D: 1.2203 	Validation Loss_G: 0.9775
# [85/1000][0/2] Loss_D: 1.1331 Loss_G: 0.8821
# Validation Loss_D: 1.2217 	Validation Loss_G: 0.9824
# [86/1000][0/2] Loss_D: 1.1290 Loss_G: 0.8942
# Validation Loss_D: 1.2214 	Validation Loss_G: 0.9871
# [87/1000][0/2] Loss_D: 1.1262 Loss_G: 0.8992
# Validation Loss_D: 1.2051 	Validation Loss_G: 1.0088
# [88/1000][0/2] Loss_D: 1.1230 Loss_G: 0.9147
# Validation Loss_D: 1.2047 	Validation Loss_G: 1.0091
# [89/1000][0/2] Loss_D: 1.1212 Loss_G: 0.8941
# Validation Loss_D: 1.1954 	Validation Loss_G: 1.0188
# [90/1000][0/2] Loss_D: 1.1186 Loss_G: 0.9051
# Validation Loss_D: 1.1918 	Validation Loss_G: 1.0175
# [91/1000][0/2] Loss_D: 1.1117 Loss_G: 0.9002
# Validation Loss_D: 1.1871 	Validation Loss_G: 1.0084
# [92/1000][0/2] Loss_D: 1.1122 Loss_G: 0.8917
# Validation Loss_D: 1.1827 	Validation Loss_G: 1.0172
# [93/1000][0/2] Loss_D: 1.1072 Loss_G: 0.9097
# Validation Loss_D: 1.1799 	Validation Loss_G: 1.0100
# [94/1000][0/2] Loss_D: 1.1044 Loss_G: 0.9004
# Validation Loss_D: 1.1800 	Validation Loss_G: 1.0032
# [95/1000][0/2] Loss_D: 1.0983 Loss_G: 0.9077
# Validation Loss_D: 1.1802 	Validation Loss_G: 1.0100
# [96/1000][0/2] Loss_D: 1.0963 Loss_G: 0.9171
# Validation Loss_D: 1.1863 	Validation Loss_G: 1.0095
# [97/1000][0/2] Loss_D: 1.0938 Loss_G: 0.9186
# Validation Loss_D: 1.1843 	Validation Loss_G: 1.0312
# [98/1000][0/2] Loss_D: 1.0874 Loss_G: 0.9382
# Validation Loss_D: 1.1715 	Validation Loss_G: 1.0538
# [99/1000][0/2] Loss_D: 1.0849 Loss_G: 0.9340
# Validation Loss_D: 1.1658 	Validation Loss_G: 1.0396
# [100/1000][0/2] Loss_D: 1.0811 Loss_G: 0.9289
# Validation Loss_D: 1.1543 	Validation Loss_G: 1.0397
# [101/1000][0/2] Loss_D: 1.0756 Loss_G: 0.9337
# Validation Loss_D: 1.1528 	Validation Loss_G: 1.0575
# [102/1000][0/2] Loss_D: 1.0727 Loss_G: 0.9322
# Validation Loss_D: 1.1672 	Validation Loss_G: 1.0459
# [103/1000][0/2] Loss_D: 1.0706 Loss_G: 0.9432
# Validation Loss_D: 1.1523 	Validation Loss_G: 1.0635
# [104/1000][0/2] Loss_D: 1.0670 Loss_G: 0.9481
# Validation Loss_D: 1.1581 	Validation Loss_G: 1.0537
# [105/1000][0/2] Loss_D: 1.0629 Loss_G: 0.9396
# Validation Loss_D: 1.1539 	Validation Loss_G: 1.0556
# Early stopping na época 105!
# Modelo salvo em: ./models_saved/dcgan/1/10/fold3/generator.pth
# Iniciando o teste ....
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.4136 Loss_G: 0.7341
# Validation Loss_D: 1.3867 	Validation Loss_G: 0.6864
# [1/1000][0/2] Loss_D: 1.4119 Loss_G: 0.7260
# Validation Loss_D: 1.3873 	Validation Loss_G: 0.6829
# [2/1000][0/2] Loss_D: 1.4118 Loss_G: 0.7288
# Validation Loss_D: 1.3880 	Validation Loss_G: 0.6872
# [3/1000][0/2] Loss_D: 1.4120 Loss_G: 0.7274
# Validation Loss_D: 1.3885 	Validation Loss_G: 0.6910
# [4/1000][0/2] Loss_D: 1.4037 Loss_G: 0.7251
# Validation Loss_D: 1.3887 	Validation Loss_G: 0.6897
# [5/1000][0/2] Loss_D: 1.4053 Loss_G: 0.7221
# Validation Loss_D: 1.3883 	Validation Loss_G: 0.6894
# [6/1000][0/2] Loss_D: 1.3988 Loss_G: 0.7249
# Validation Loss_D: 1.3881 	Validation Loss_G: 0.6921
# [7/1000][0/2] Loss_D: 1.3993 Loss_G: 0.7167
# Validation Loss_D: 1.3887 	Validation Loss_G: 0.6945
# [8/1000][0/2] Loss_D: 1.3890 Loss_G: 0.7248
# Validation Loss_D: 1.3871 	Validation Loss_G: 0.6939
# [9/1000][0/2] Loss_D: 1.3883 Loss_G: 0.7231
# Validation Loss_D: 1.3822 	Validation Loss_G: 0.7045
# [10/1000][0/2] Loss_D: 1.3859 Loss_G: 0.7335
# Validation Loss_D: 1.3776 	Validation Loss_G: 0.7167
# [11/1000][0/2] Loss_D: 1.3811 Loss_G: 0.7328
# Validation Loss_D: 1.3756 	Validation Loss_G: 0.7237
# [12/1000][0/2] Loss_D: 1.3725 Loss_G: 0.7389
# Validation Loss_D: 1.3691 	Validation Loss_G: 0.7415
# [13/1000][0/2] Loss_D: 1.3678 Loss_G: 0.7389
# Validation Loss_D: 1.3677 	Validation Loss_G: 0.7476
# [14/1000][0/2] Loss_D: 1.3651 Loss_G: 0.7391
# Validation Loss_D: 1.3644 	Validation Loss_G: 0.7550
# [15/1000][0/2] Loss_D: 1.3563 Loss_G: 0.7479
# Validation Loss_D: 1.3678 	Validation Loss_G: 0.7526
# [16/1000][0/2] Loss_D: 1.3548 Loss_G: 0.7427
# Validation Loss_D: 1.3602 	Validation Loss_G: 0.7666
# [17/1000][0/2] Loss_D: 1.3536 Loss_G: 0.7478
# Validation Loss_D: 1.3548 	Validation Loss_G: 0.7834
# [18/1000][0/2] Loss_D: 1.3447 Loss_G: 0.7622
# Validation Loss_D: 1.3471 	Validation Loss_G: 0.7951
# [19/1000][0/2] Loss_D: 1.3447 Loss_G: 0.7550
# Validation Loss_D: 1.3465 	Validation Loss_G: 0.7938
# [20/1000][0/2] Loss_D: 1.3407 Loss_G: 0.7596
# Validation Loss_D: 1.3434 	Validation Loss_G: 0.8028
# [21/1000][0/2] Loss_D: 1.3407 Loss_G: 0.7606
# Validation Loss_D: 1.3416 	Validation Loss_G: 0.8082
# [22/1000][0/2] Loss_D: 1.3375 Loss_G: 0.7638
# Validation Loss_D: 1.3374 	Validation Loss_G: 0.8162
# [23/1000][0/2] Loss_D: 1.3327 Loss_G: 0.7659
# Validation Loss_D: 1.3369 	Validation Loss_G: 0.8016
# [24/1000][0/2] Loss_D: 1.3260 Loss_G: 0.7561
# Validation Loss_D: 1.3466 	Validation Loss_G: 0.7759
# [25/1000][0/2] Loss_D: 1.3272 Loss_G: 0.7461
# Validation Loss_D: 1.3431 	Validation Loss_G: 0.7817
# [26/1000][0/2] Loss_D: 1.3278 Loss_G: 0.7488
# Validation Loss_D: 1.3427 	Validation Loss_G: 0.7935
# [27/1000][0/2] Loss_D: 1.3254 Loss_G: 0.7565
# Validation Loss_D: 1.3323 	Validation Loss_G: 0.8099
# [28/1000][0/2] Loss_D: 1.3200 Loss_G: 0.7639
# Validation Loss_D: 1.3308 	Validation Loss_G: 0.8140
# [29/1000][0/2] Loss_D: 1.3203 Loss_G: 0.7632
# Validation Loss_D: 1.3303 	Validation Loss_G: 0.8286
# [30/1000][0/2] Loss_D: 1.3252 Loss_G: 0.7673
# Validation Loss_D: 1.3225 	Validation Loss_G: 0.8482
# [31/1000][0/2] Loss_D: 1.3210 Loss_G: 0.7732
# Validation Loss_D: 1.3177 	Validation Loss_G: 0.8457
# [32/1000][0/2] Loss_D: 1.3191 Loss_G: 0.7641
# Validation Loss_D: 1.3247 	Validation Loss_G: 0.8263
# [33/1000][0/2] Loss_D: 1.3177 Loss_G: 0.7561
# Validation Loss_D: 1.3176 	Validation Loss_G: 0.8242
# [34/1000][0/2] Loss_D: 1.3213 Loss_G: 0.7536
# Validation Loss_D: 1.3227 	Validation Loss_G: 0.8321
# [35/1000][0/2] Loss_D: 1.3203 Loss_G: 0.7591
# Validation Loss_D: 1.3107 	Validation Loss_G: 0.8458
# [36/1000][0/2] Loss_D: 1.3205 Loss_G: 0.7619
# Validation Loss_D: 1.3096 	Validation Loss_G: 0.8533
# [37/1000][0/2] Loss_D: 1.3253 Loss_G: 0.7499
# Validation Loss_D: 1.3090 	Validation Loss_G: 0.8493
# [38/1000][0/2] Loss_D: 1.3232 Loss_G: 0.7514
# Validation Loss_D: 1.3133 	Validation Loss_G: 0.8471
# [39/1000][0/2] Loss_D: 1.3238 Loss_G: 0.7583
# Validation Loss_D: 1.3108 	Validation Loss_G: 0.8569
# [40/1000][0/2] Loss_D: 1.3212 Loss_G: 0.7577
# Validation Loss_D: 1.3073 	Validation Loss_G: 0.8582
# [41/1000][0/2] Loss_D: 1.3238 Loss_G: 0.7534
# Validation Loss_D: 1.3098 	Validation Loss_G: 0.8595
# [42/1000][0/2] Loss_D: 1.3222 Loss_G: 0.7500
# Validation Loss_D: 1.3041 	Validation Loss_G: 0.8672
# [43/1000][0/2] Loss_D: 1.3216 Loss_G: 0.7507
# Validation Loss_D: 1.3029 	Validation Loss_G: 0.8725
# [44/1000][0/2] Loss_D: 1.3172 Loss_G: 0.7548
# Validation Loss_D: 1.3097 	Validation Loss_G: 0.8576
# [45/1000][0/2] Loss_D: 1.3203 Loss_G: 0.7498
# Validation Loss_D: 1.3100 	Validation Loss_G: 0.8587
# [46/1000][0/2] Loss_D: 1.3224 Loss_G: 0.7531
# Validation Loss_D: 1.3022 	Validation Loss_G: 0.8639
# [47/1000][0/2] Loss_D: 1.3196 Loss_G: 0.7457
# Validation Loss_D: 1.3041 	Validation Loss_G: 0.8624
# [48/1000][0/2] Loss_D: 1.3210 Loss_G: 0.7517
# Validation Loss_D: 1.2978 	Validation Loss_G: 0.8803
# [49/1000][0/2] Loss_D: 1.3191 Loss_G: 0.7563
# Validation Loss_D: 1.3047 	Validation Loss_G: 0.8918
# [50/1000][0/2] Loss_D: 1.3179 Loss_G: 0.7616
# Validation Loss_D: 1.2987 	Validation Loss_G: 0.9140
# [51/1000][0/2] Loss_D: 1.3182 Loss_G: 0.7667
# Validation Loss_D: 1.3051 	Validation Loss_G: 0.9065
# [52/1000][0/2] Loss_D: 1.3172 Loss_G: 0.7702
# Validation Loss_D: 1.3034 	Validation Loss_G: 0.9124
# [53/1000][0/2] Loss_D: 1.3163 Loss_G: 0.7661
# Validation Loss_D: 1.2994 	Validation Loss_G: 0.9085
# [54/1000][0/2] Loss_D: 1.3149 Loss_G: 0.7651
# Validation Loss_D: 1.3002 	Validation Loss_G: 0.9079
# [55/1000][0/2] Loss_D: 1.3134 Loss_G: 0.7673
# Validation Loss_D: 1.3037 	Validation Loss_G: 0.9064
# [56/1000][0/2] Loss_D: 1.3107 Loss_G: 0.7744
# Validation Loss_D: 1.2957 	Validation Loss_G: 0.9232
# [57/1000][0/2] Loss_D: 1.3119 Loss_G: 0.7629
# Validation Loss_D: 1.2972 	Validation Loss_G: 0.9073
# [58/1000][0/2] Loss_D: 1.3075 Loss_G: 0.7683
# Validation Loss_D: 1.3079 	Validation Loss_G: 0.9042
# [59/1000][0/2] Loss_D: 1.3084 Loss_G: 0.7681
# Validation Loss_D: 1.3021 	Validation Loss_G: 0.9186
# [60/1000][0/2] Loss_D: 1.3068 Loss_G: 0.7637
# Validation Loss_D: 1.2982 	Validation Loss_G: 0.9224
# [61/1000][0/2] Loss_D: 1.3053 Loss_G: 0.7698
# Validation Loss_D: 1.2957 	Validation Loss_G: 0.9379
# [62/1000][0/2] Loss_D: 1.3041 Loss_G: 0.7850
# Validation Loss_D: 1.2917 	Validation Loss_G: 0.9389
# [63/1000][0/2] Loss_D: 1.2999 Loss_G: 0.7818
# Validation Loss_D: 1.2988 	Validation Loss_G: 0.9238
# [64/1000][0/2] Loss_D: 1.3003 Loss_G: 0.7821
# Validation Loss_D: 1.2973 	Validation Loss_G: 0.9245
# [65/1000][0/2] Loss_D: 1.2997 Loss_G: 0.7824
# Validation Loss_D: 1.2953 	Validation Loss_G: 0.9238
# [66/1000][0/2] Loss_D: 1.2987 Loss_G: 0.7740
# Validation Loss_D: 1.2986 	Validation Loss_G: 0.9254
# [67/1000][0/2] Loss_D: 1.2996 Loss_G: 0.7758
# Validation Loss_D: 1.3014 	Validation Loss_G: 0.9214
# [68/1000][0/2] Loss_D: 1.2983 Loss_G: 0.7804
# Validation Loss_D: 1.2880 	Validation Loss_G: 0.9497
# [69/1000][0/2] Loss_D: 1.2945 Loss_G: 0.7958
# Validation Loss_D: 1.2932 	Validation Loss_G: 0.9552
# [70/1000][0/2] Loss_D: 1.2961 Loss_G: 0.7877
# Validation Loss_D: 1.2930 	Validation Loss_G: 0.9476
# [71/1000][0/2] Loss_D: 1.2983 Loss_G: 0.7770
# Validation Loss_D: 1.2872 	Validation Loss_G: 0.9598
# [72/1000][0/2] Loss_D: 1.2975 Loss_G: 0.7746
# Validation Loss_D: 1.2888 	Validation Loss_G: 0.9546
# [73/1000][0/2] Loss_D: 1.2989 Loss_G: 0.7741
# Validation Loss_D: 1.2854 	Validation Loss_G: 0.9565
# [74/1000][0/2] Loss_D: 1.2991 Loss_G: 0.7720
# Validation Loss_D: 1.2884 	Validation Loss_G: 0.9349
# [75/1000][0/2] Loss_D: 1.2993 Loss_G: 0.7625
# Validation Loss_D: 1.2844 	Validation Loss_G: 0.9323
# [76/1000][0/2] Loss_D: 1.3032 Loss_G: 0.7587
# Validation Loss_D: 1.2852 	Validation Loss_G: 0.9342
# [77/1000][0/2] Loss_D: 1.3026 Loss_G: 0.7606
# Validation Loss_D: 1.2882 	Validation Loss_G: 0.9304
# [78/1000][0/2] Loss_D: 1.3023 Loss_G: 0.7571
# Validation Loss_D: 1.2875 	Validation Loss_G: 0.9402
# [79/1000][0/2] Loss_D: 1.3041 Loss_G: 0.7624
# Validation Loss_D: 1.2910 	Validation Loss_G: 0.9510
# [80/1000][0/2] Loss_D: 1.3069 Loss_G: 0.7618
# Validation Loss_D: 1.2884 	Validation Loss_G: 0.9638
# [81/1000][0/2] Loss_D: 1.3056 Loss_G: 0.7769
# Validation Loss_D: 1.2915 	Validation Loss_G: 0.9763
# [82/1000][0/2] Loss_D: 1.3082 Loss_G: 0.7768
# Validation Loss_D: 1.2934 	Validation Loss_G: 0.9714
# [83/1000][0/2] Loss_D: 1.3048 Loss_G: 0.7716
# Validation Loss_D: 1.2840 	Validation Loss_G: 0.9733
# [84/1000][0/2] Loss_D: 1.3083 Loss_G: 0.7640
# Validation Loss_D: 1.2848 	Validation Loss_G: 0.9689
# [85/1000][0/2] Loss_D: 1.3097 Loss_G: 0.7580
# Validation Loss_D: 1.2879 	Validation Loss_G: 0.9605
# [86/1000][0/2] Loss_D: 1.3127 Loss_G: 0.7558
# Validation Loss_D: 1.2924 	Validation Loss_G: 0.9627
# [87/1000][0/2] Loss_D: 1.3107 Loss_G: 0.7629
# Validation Loss_D: 1.2870 	Validation Loss_G: 0.9761
# [88/1000][0/2] Loss_D: 1.3097 Loss_G: 0.7643
# Validation Loss_D: 1.2885 	Validation Loss_G: 0.9732
# [89/1000][0/2] Loss_D: 1.3092 Loss_G: 0.7645
# Validation Loss_D: 1.2816 	Validation Loss_G: 0.9879
# [90/1000][0/2] Loss_D: 1.3096 Loss_G: 0.7682
# Validation Loss_D: 1.2810 	Validation Loss_G: 0.9961
# [91/1000][0/2] Loss_D: 1.3079 Loss_G: 0.7641
# Validation Loss_D: 1.2806 	Validation Loss_G: 0.9862
# [92/1000][0/2] Loss_D: 1.3092 Loss_G: 0.7661
# Validation Loss_D: 1.2795 	Validation Loss_G: 0.9836
# [93/1000][0/2] Loss_D: 1.3061 Loss_G: 0.7685
# Validation Loss_D: 1.2799 	Validation Loss_G: 0.9882
# [94/1000][0/2] Loss_D: 1.3050 Loss_G: 0.7637
# Validation Loss_D: 1.2785 	Validation Loss_G: 0.9863
# [95/1000][0/2] Loss_D: 1.3056 Loss_G: 0.7563
# Validation Loss_D: 1.2818 	Validation Loss_G: 0.9890
# [96/1000][0/2] Loss_D: 1.3049 Loss_G: 0.7667
# Validation Loss_D: 1.2817 	Validation Loss_G: 0.9949
# [97/1000][0/2] Loss_D: 1.3023 Loss_G: 0.7693
# Validation Loss_D: 1.2797 	Validation Loss_G: 1.0014
# [98/1000][0/2] Loss_D: 1.3039 Loss_G: 0.7680
# Validation Loss_D: 1.2801 	Validation Loss_G: 1.0017
# [99/1000][0/2] Loss_D: 1.3064 Loss_G: 0.7673
# Validation Loss_D: 1.2729 	Validation Loss_G: 1.0341
# [100/1000][0/2] Loss_D: 1.3026 Loss_G: 0.7769
# Validation Loss_D: 1.2718 	Validation Loss_G: 1.0330
# [101/1000][0/2] Loss_D: 1.3044 Loss_G: 0.7643
# Validation Loss_D: 1.2777 	Validation Loss_G: 1.0231
# Early stopping na época 101!
# Modelo salvo em: ./models_saved/dcgan/1/10/fold4/generator.pth
# Iniciando o teste ....
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.4653 Loss_G: 0.8176
# Validation Loss_D: 1.3874 	Validation Loss_G: 0.7077
# [1/1000][0/2] Loss_D: 1.4524 Loss_G: 0.7393
# Validation Loss_D: 1.3889 	Validation Loss_G: 0.7184
# [2/1000][0/2] Loss_D: 1.4480 Loss_G: 0.7189
# Validation Loss_D: 1.3909 	Validation Loss_G: 0.7250
# [3/1000][0/2] Loss_D: 1.4459 Loss_G: 0.7169
# Validation Loss_D: 1.3929 	Validation Loss_G: 0.7250
# [4/1000][0/2] Loss_D: 1.4405 Loss_G: 0.7173
# Validation Loss_D: 1.3961 	Validation Loss_G: 0.7256
# [5/1000][0/2] Loss_D: 1.4371 Loss_G: 0.7115
# Validation Loss_D: 1.3972 	Validation Loss_G: 0.7217
# [6/1000][0/2] Loss_D: 1.4318 Loss_G: 0.7068
# Validation Loss_D: 1.3971 	Validation Loss_G: 0.7229
# [7/1000][0/2] Loss_D: 1.4285 Loss_G: 0.7094
# Validation Loss_D: 1.3948 	Validation Loss_G: 0.7309
# [8/1000][0/2] Loss_D: 1.4206 Loss_G: 0.7147
# Validation Loss_D: 1.3894 	Validation Loss_G: 0.7413
# [9/1000][0/2] Loss_D: 1.4158 Loss_G: 0.7208
# Validation Loss_D: 1.3864 	Validation Loss_G: 0.7582
# [10/1000][0/2] Loss_D: 1.4115 Loss_G: 0.7271
# Validation Loss_D: 1.3822 	Validation Loss_G: 0.7650
# [11/1000][0/2] Loss_D: 1.4094 Loss_G: 0.7216
# Validation Loss_D: 1.3801 	Validation Loss_G: 0.7620
# [12/1000][0/2] Loss_D: 1.4001 Loss_G: 0.7270
# Validation Loss_D: 1.3746 	Validation Loss_G: 0.7593
# [13/1000][0/2] Loss_D: 1.3981 Loss_G: 0.7311
# Validation Loss_D: 1.3753 	Validation Loss_G: 0.7677
# [14/1000][0/2] Loss_D: 1.3900 Loss_G: 0.7305
# Validation Loss_D: 1.3670 	Validation Loss_G: 0.7644
# [15/1000][0/2] Loss_D: 1.3858 Loss_G: 0.7338
# Validation Loss_D: 1.3642 	Validation Loss_G: 0.7640
# [16/1000][0/2] Loss_D: 1.3825 Loss_G: 0.7401
# Validation Loss_D: 1.3567 	Validation Loss_G: 0.7834
# [17/1000][0/2] Loss_D: 1.3752 Loss_G: 0.7410
# Validation Loss_D: 1.3552 	Validation Loss_G: 0.7853
# [18/1000][0/2] Loss_D: 1.3699 Loss_G: 0.7438
# Validation Loss_D: 1.3452 	Validation Loss_G: 0.7954
# [19/1000][0/2] Loss_D: 1.3657 Loss_G: 0.7478
# Validation Loss_D: 1.3374 	Validation Loss_G: 0.8100
# [20/1000][0/2] Loss_D: 1.3638 Loss_G: 0.7497
# Validation Loss_D: 1.3347 	Validation Loss_G: 0.8120
# [21/1000][0/2] Loss_D: 1.3600 Loss_G: 0.7563
# Validation Loss_D: 1.3258 	Validation Loss_G: 0.8214
# [22/1000][0/2] Loss_D: 1.3556 Loss_G: 0.7596
# Validation Loss_D: 1.3288 	Validation Loss_G: 0.8211
# [23/1000][0/2] Loss_D: 1.3505 Loss_G: 0.7618
# Validation Loss_D: 1.3222 	Validation Loss_G: 0.8254
# [24/1000][0/2] Loss_D: 1.3472 Loss_G: 0.7633
# Validation Loss_D: 1.3177 	Validation Loss_G: 0.8196
# [25/1000][0/2] Loss_D: 1.3450 Loss_G: 0.7499
# Validation Loss_D: 1.3229 	Validation Loss_G: 0.8001
# [26/1000][0/2] Loss_D: 1.3425 Loss_G: 0.7479
# Validation Loss_D: 1.3180 	Validation Loss_G: 0.8031
# [27/1000][0/2] Loss_D: 1.3373 Loss_G: 0.7584
# Validation Loss_D: 1.3154 	Validation Loss_G: 0.8231
# [28/1000][0/2] Loss_D: 1.3358 Loss_G: 0.7603
# Validation Loss_D: 1.3124 	Validation Loss_G: 0.8287
# [29/1000][0/2] Loss_D: 1.3341 Loss_G: 0.7670
# Validation Loss_D: 1.3105 	Validation Loss_G: 0.8352
# [30/1000][0/2] Loss_D: 1.3299 Loss_G: 0.7620
# Validation Loss_D: 1.3142 	Validation Loss_G: 0.8213
# [31/1000][0/2] Loss_D: 1.3272 Loss_G: 0.7562
# Validation Loss_D: 1.3102 	Validation Loss_G: 0.8248
# [32/1000][0/2] Loss_D: 1.3275 Loss_G: 0.7514
# Validation Loss_D: 1.3083 	Validation Loss_G: 0.8262
# [33/1000][0/2] Loss_D: 1.3252 Loss_G: 0.7527
# Validation Loss_D: 1.3044 	Validation Loss_G: 0.8239
# [34/1000][0/2] Loss_D: 1.3238 Loss_G: 0.7573
# Validation Loss_D: 1.2944 	Validation Loss_G: 0.8428
# [35/1000][0/2] Loss_D: 1.3228 Loss_G: 0.7632
# Validation Loss_D: 1.2893 	Validation Loss_G: 0.8540
# [36/1000][0/2] Loss_D: 1.3179 Loss_G: 0.7639
# Validation Loss_D: 1.2917 	Validation Loss_G: 0.8480
# [37/1000][0/2] Loss_D: 1.3156 Loss_G: 0.7751
# Validation Loss_D: 1.2857 	Validation Loss_G: 0.8628
# [38/1000][0/2] Loss_D: 1.3148 Loss_G: 0.7755
# Validation Loss_D: 1.2847 	Validation Loss_G: 0.8595
# [39/1000][0/2] Loss_D: 1.3115 Loss_G: 0.7798
# Validation Loss_D: 1.2864 	Validation Loss_G: 0.8563
# [40/1000][0/2] Loss_D: 1.3096 Loss_G: 0.7802
# Validation Loss_D: 1.2822 	Validation Loss_G: 0.8637
# [41/1000][0/2] Loss_D: 1.3070 Loss_G: 0.7808
# Validation Loss_D: 1.2785 	Validation Loss_G: 0.8671
# [42/1000][0/2] Loss_D: 1.3055 Loss_G: 0.7778
# Validation Loss_D: 1.2727 	Validation Loss_G: 0.8684
# [43/1000][0/2] Loss_D: 1.3025 Loss_G: 0.7802
# Validation Loss_D: 1.2700 	Validation Loss_G: 0.8791
# [44/1000][0/2] Loss_D: 1.2993 Loss_G: 0.7867
# Validation Loss_D: 1.2707 	Validation Loss_G: 0.8816
# [45/1000][0/2] Loss_D: 1.2999 Loss_G: 0.7840
# Validation Loss_D: 1.2669 	Validation Loss_G: 0.8739
# [46/1000][0/2] Loss_D: 1.2984 Loss_G: 0.7773
# Validation Loss_D: 1.2701 	Validation Loss_G: 0.8796
# [47/1000][0/2] Loss_D: 1.2936 Loss_G: 0.7906
# Validation Loss_D: 1.2638 	Validation Loss_G: 0.8871
# [48/1000][0/2] Loss_D: 1.2933 Loss_G: 0.7857
# Validation Loss_D: 1.2649 	Validation Loss_G: 0.8856
# [49/1000][0/2] Loss_D: 1.2923 Loss_G: 0.7862
# Validation Loss_D: 1.2653 	Validation Loss_G: 0.8905
# [50/1000][0/2] Loss_D: 1.2905 Loss_G: 0.7770
# Validation Loss_D: 1.2635 	Validation Loss_G: 0.8850
# [51/1000][0/2] Loss_D: 1.2880 Loss_G: 0.7747
# Validation Loss_D: 1.2593 	Validation Loss_G: 0.8866
# [52/1000][0/2] Loss_D: 1.2875 Loss_G: 0.7817
# Validation Loss_D: 1.2602 	Validation Loss_G: 0.8898
# [53/1000][0/2] Loss_D: 1.2860 Loss_G: 0.7799
# Validation Loss_D: 1.2635 	Validation Loss_G: 0.8953
# [54/1000][0/2] Loss_D: 1.2818 Loss_G: 0.7871
# Validation Loss_D: 1.2600 	Validation Loss_G: 0.8912
# [55/1000][0/2] Loss_D: 1.2817 Loss_G: 0.7896
# Validation Loss_D: 1.2541 	Validation Loss_G: 0.9218
# [56/1000][0/2] Loss_D: 1.2790 Loss_G: 0.8116
# Validation Loss_D: 1.2482 	Validation Loss_G: 0.9348
# [57/1000][0/2] Loss_D: 1.2780 Loss_G: 0.8025
# Validation Loss_D: 1.2500 	Validation Loss_G: 0.9315
# [58/1000][0/2] Loss_D: 1.2733 Loss_G: 0.8022
# Validation Loss_D: 1.2494 	Validation Loss_G: 0.9231
# [59/1000][0/2] Loss_D: 1.2735 Loss_G: 0.8000
# Validation Loss_D: 1.2403 	Validation Loss_G: 0.9253
# [60/1000][0/2] Loss_D: 1.2706 Loss_G: 0.8061
# Validation Loss_D: 1.2473 	Validation Loss_G: 0.9276
# [61/1000][0/2] Loss_D: 1.2674 Loss_G: 0.8113
# Validation Loss_D: 1.2469 	Validation Loss_G: 0.9217
# [62/1000][0/2] Loss_D: 1.2660 Loss_G: 0.8094
# Validation Loss_D: 1.2385 	Validation Loss_G: 0.9310
# [63/1000][0/2] Loss_D: 1.2629 Loss_G: 0.8082
# Validation Loss_D: 1.2414 	Validation Loss_G: 0.9273
# [64/1000][0/2] Loss_D: 1.2603 Loss_G: 0.8137
# Validation Loss_D: 1.2444 	Validation Loss_G: 0.9276
# ...
# [66/1000][0/2] Loss_D: 1.1097 Loss_G: 0.9399
# Validation Loss_D: 1.1098 	Validation Loss_G: 0.9225
# [67/1000][0/2] Loss_D: 1.1158 Loss_G: 0.9296
# Validation Loss_D: 1.1274 	Validation Loss_G: 0.9041
# [68/1000][0/2] Loss_D: 1.1156 Loss_G: 0.9300
# Validation Loss_D: 1.1381 	Validation Loss_G: 0.8894
# [69/1000][0/2] Loss_D: 1.1231 Loss_G: 0.9213
# Validation Loss_D: 1.1585 	Validation Loss_G: 0.8679
# [70/1000][0/2] Loss_D: 1.1285 Loss_G: 0.9217
# Validation Loss_D: 1.2011 	Validation Loss_G: 0.8305
# [71/1000][0/2] Loss_D: 1.1472 Loss_G: 0.9015
# Validation Loss_D: 1.2180 	Validation Loss_G: 0.8236
# [72/1000][0/2] Loss_D: 1.1494 Loss_G: 0.9094
# Validation Loss_D: 1.1974 	Validation Loss_G: 0.8518
# [73/1000][0/2] Loss_D: 1.1334 Loss_G: 0.9343
# Validation Loss_D: 1.2069 	Validation Loss_G: 0.8438
# [74/1000][0/2] Loss_D: 1.1280 Loss_G: 0.9374
# Validation Loss_D: 1.2193 	Validation Loss_G: 0.8405
# [75/1000][0/2] Loss_D: 1.1257 Loss_G: 0.9399
# Validation Loss_D: 1.2241 	Validation Loss_G: 0.8490
# [76/1000][0/2] Loss_D: 1.1226 Loss_G: 0.9352
# Validation Loss_D: 1.2317 	Validation Loss_G: 0.8291
# [77/1000][0/2] Loss_D: 1.1134 Loss_G: 0.9371
# Validation Loss_D: 1.2202 	Validation Loss_G: 0.8451
# [78/1000][0/2] Loss_D: 1.0965 Loss_G: 0.9561
# Validation Loss_D: 1.1943 	Validation Loss_G: 0.8740
# [79/1000][0/2] Loss_D: 1.0802 Loss_G: 0.9713
# Validation Loss_D: 1.1884 	Validation Loss_G: 0.8854
# [80/1000][0/2] Loss_D: 1.0720 Loss_G: 0.9763
# Validation Loss_D: 1.1975 	Validation Loss_G: 0.8737
# [81/1000][0/2] Loss_D: 1.0803 Loss_G: 0.9603
# Validation Loss_D: 1.2002 	Validation Loss_G: 0.8708
# [82/1000][0/2] Loss_D: 1.0825 Loss_G: 0.9574
# Validation Loss_D: 1.1952 	Validation Loss_G: 0.8794
# [83/1000][0/2] Loss_D: 1.0742 Loss_G: 0.9618
# Validation Loss_D: 1.1817 	Validation Loss_G: 0.9122
# [84/1000][0/2] Loss_D: 1.0601 Loss_G: 0.9748
# Validation Loss_D: 1.1629 	Validation Loss_G: 0.9503
# [85/1000][0/2] Loss_D: 1.0479 Loss_G: 0.9881
# Validation Loss_D: 1.1610 	Validation Loss_G: 0.9599
# [86/1000][0/2] Loss_D: 1.0421 Loss_G: 0.9930
# Validation Loss_D: 1.1442 	Validation Loss_G: 0.9823
# [87/1000][0/2] Loss_D: 1.0219 Loss_G: 1.0157
# Validation Loss_D: 1.1196 	Validation Loss_G: 1.0102
# [88/1000][0/2] Loss_D: 1.0029 Loss_G: 1.0349
# Validation Loss_D: 1.1152 	Validation Loss_G: 1.0085
# [89/1000][0/2] Loss_D: 0.9878 Loss_G: 1.0461
# Validation Loss_D: 1.1263 	Validation Loss_G: 0.9923
# [90/1000][0/2] Loss_D: 0.9871 Loss_G: 1.0401
# Validation Loss_D: 1.1419 	Validation Loss_G: 0.9619
# [91/1000][0/2] Loss_D: 0.9871 Loss_G: 1.0364
# Validation Loss_D: 1.1584 	Validation Loss_G: 0.9526
# [92/1000][0/2] Loss_D: 0.9972 Loss_G: 1.0123
# Validation Loss_D: 1.1678 	Validation Loss_G: 0.9409
# [93/1000][0/2] Loss_D: 0.9951 Loss_G: 1.0184
# Validation Loss_D: 1.1617 	Validation Loss_G: 0.9638
# [94/1000][0/2] Loss_D: 0.9830 Loss_G: 1.0248
# Validation Loss_D: 1.1499 	Validation Loss_G: 0.9734
# [95/1000][0/2] Loss_D: 0.9642 Loss_G: 1.0466
# Validation Loss_D: 1.1429 	Validation Loss_G: 0.9945
# [96/1000][0/2] Loss_D: 0.9398 Loss_G: 1.0781
# Validation Loss_D: 1.1208 	Validation Loss_G: 1.0284
# [97/1000][0/2] Loss_D: 0.9176 Loss_G: 1.1056
# Validation Loss_D: 1.1060 	Validation Loss_G: 1.0501
# [98/1000][0/2] Loss_D: 0.8928 Loss_G: 1.1314
# Validation Loss_D: 1.1092 	Validation Loss_G: 1.0475
# [99/1000][0/2] Loss_D: 0.8838 Loss_G: 1.1297
# Validation Loss_D: 1.1204 	Validation Loss_G: 1.0324
# [100/1000][0/2] Loss_D: 0.8800 Loss_G: 1.1282
# Validation Loss_D: 1.1212 	Validation Loss_G: 1.0315
# [101/1000][0/2] Loss_D: 0.8775 Loss_G: 1.1241
# Validation Loss_D: 1.1245 	Validation Loss_G: 1.0136
# [102/1000][0/2] Loss_D: 0.8844 Loss_G: 1.1121
# Validation Loss_D: 1.1416 	Validation Loss_G: 0.9870
# [103/1000][0/2] Loss_D: 0.8873 Loss_G: 1.1138
# Validation Loss_D: 1.1473 	Validation Loss_G: 0.9846
# [104/1000][0/2] Loss_D: 0.8884 Loss_G: 1.1136
# Validation Loss_D: 1.1500 	Validation Loss_G: 0.9858
# [105/1000][0/2] Loss_D: 0.8822 Loss_G: 1.1234
# Validation Loss_D: 1.1721 	Validation Loss_G: 0.9564
# [106/1000][0/2] Loss_D: 0.8897 Loss_G: 1.1047
# Validation Loss_D: 1.1943 	Validation Loss_G: 0.9367
# [107/1000][0/2] Loss_D: 0.9097 Loss_G: 1.0787
# Validation Loss_D: 1.2122 	Validation Loss_G: 0.9223
# [108/1000][0/2] Loss_D: 0.9165 Loss_G: 1.0787
# Validation Loss_D: 1.2214 	Validation Loss_G: 0.9248
# [109/1000][0/2] Loss_D: 0.9149 Loss_G: 1.0837
# Validation Loss_D: 1.2328 	Validation Loss_G: 0.9333
# [110/1000][0/2] Loss_D: 0.9053 Loss_G: 1.0960
# Validation Loss_D: 1.2338 	Validation Loss_G: 0.9380
# Early stopping na época 110!
# Modelo salvo em: ./models_saved/dcgan/3/40/fold4/generator.pth
# Iniciando o teste ....
# Starting Training Loop...
# [0/1000][0/2] Loss_D: 1.3959 Loss_G: 0.9509
# Validation Loss_D: 1.3821 	Validation Loss_G: 0.7008
# [1/1000][0/2] Loss_D: 1.9422 Loss_G: 0.4722
# Validation Loss_D: 1.3795 	Validation Loss_G: 0.7109
# [2/1000][0/2] Loss_D: 2.2896 Loss_G: 0.3372
# Validation Loss_D: 1.3768 	Validation Loss_G: 0.7239
# [3/1000][0/2] Loss_D: 2.4427 Loss_G: 0.2963
# Validation Loss_D: 1.3786 	Validation Loss_G: 0.7350
# [4/1000][0/2] Loss_D: 2.5026 Loss_G: 0.2851
# Validation Loss_D: 1.3936 	Validation Loss_G: 0.7323
# [5/1000][0/2] Loss_D: 2.5048 Loss_G: 0.2877
# Validation Loss_D: 1.4283 	Validation Loss_G: 0.7198
# [6/1000][0/2] Loss_D: 2.4696 Loss_G: 0.3004
# Validation Loss_D: 1.4972 	Validation Loss_G: 0.6785
# [7/1000][0/2] Loss_D: 2.4140 Loss_G: 0.3179
# Validation Loss_D: 1.5977 	Validation Loss_G: 0.6189
# [8/1000][0/2] Loss_D: 2.3573 Loss_G: 0.3373
# Validation Loss_D: 1.7301 	Validation Loss_G: 0.5492
# [9/1000][0/2] Loss_D: 2.3078 Loss_G: 0.3559
# Validation Loss_D: 1.8583 	Validation Loss_G: 0.4855
# [10/1000][0/2] Loss_D: 2.2387 Loss_G: 0.3813
# Validation Loss_D: 1.9648 	Validation Loss_G: 0.4373
# [11/1000][0/2] Loss_D: 2.1720 Loss_G: 0.4068
# Validation Loss_D: 2.0460 	Validation Loss_G: 0.4101
# [12/1000][0/2] Loss_D: 2.1295 Loss_G: 0.4235
# Validation Loss_D: 2.0938 	Validation Loss_G: 0.3923
# [13/1000][0/2] Loss_D: 2.0999 Loss_G: 0.4331
# Validation Loss_D: 2.1113 	Validation Loss_G: 0.3880
# [14/1000][0/2] Loss_D: 2.0747 Loss_G: 0.4436
# Validation Loss_D: 2.1193 	Validation Loss_G: 0.3849
# [15/1000][0/2] Loss_D: 2.0572 Loss_G: 0.4527
# Validation Loss_D: 2.1017 	Validation Loss_G: 0.3919
# [16/1000][0/2] Loss_D: 2.0325 Loss_G: 0.4645
# Validation Loss_D: 2.0402 	Validation Loss_G: 0.4147
# [17/1000][0/2] Loss_D: 1.9929 Loss_G: 0.4845
# Validation Loss_D: 1.9670 	Validation Loss_G: 0.4484
# [18/1000][0/2] Loss_D: 1.9519 Loss_G: 0.5048
# Validation Loss_D: 1.9086 	Validation Loss_G: 0.4702
# [19/1000][0/2] Loss_D: 1.9221 Loss_G: 0.5209
# Validation Loss_D: 1.8587 	Validation Loss_G: 0.4982
# [20/1000][0/2] Loss_D: 1.8892 Loss_G: 0.5357
# Validation Loss_D: 1.8066 	Validation Loss_G: 0.5256
# [21/1000][0/2] Loss_D: 1.8489 Loss_G: 0.5593
# Validation Loss_D: 1.7593 	Validation Loss_G: 0.5470
# [22/1000][0/2] Loss_D: 1.8117 Loss_G: 0.5804
# Validation Loss_D: 1.7436 	Validation Loss_G: 0.5487
# [23/1000][0/2] Loss_D: 1.7899 Loss_G: 0.5866
# Validation Loss_D: 1.7326 	Validation Loss_G: 0.5489
# [24/1000][0/2] Loss_D: 1.7784 Loss_G: 0.5920
# Validation Loss_D: 1.7217 	Validation Loss_G: 0.5491
# [25/1000][0/2] Loss_D: 1.7655 Loss_G: 0.5992
# Validation Loss_D: 1.7189 	Validation Loss_G: 0.5435
# [26/1000][0/2] Loss_D: 1.7553 Loss_G: 0.6043
# Validation Loss_D: 1.7156 	Validation Loss_G: 0.5458
# [27/1000][0/2] Loss_D: 1.7376 Loss_G: 0.6118
# Validation Loss_D: 1.6953 	Validation Loss_G: 0.5649
# [28/1000][0/2] Loss_D: 1.7203 Loss_G: 0.6208
# Validation Loss_D: 1.6560 	Validation Loss_G: 0.5921
# [29/1000][0/2] Loss_D: 1.7028 Loss_G: 0.6309
# Validation Loss_D: 1.6263 	Validation Loss_G: 0.6112
# [30/1000][0/2] Loss_D: 1.6850 Loss_G: 0.6390
# Validation Loss_D: 1.6149 	Validation Loss_G: 0.6100
# [31/1000][0/2] Loss_D: 1.6719 Loss_G: 0.6458
# Validation Loss_D: 1.6198 	Validation Loss_G: 0.6008
# [32/1000][0/2] Loss_D: 1.6592 Loss_G: 0.6499
# Validation Loss_D: 1.5996 	Validation Loss_G: 0.6038
# [33/1000][0/2] Loss_D: 1.6363 Loss_G: 0.6611
# Validation Loss_D: 1.5829 	Validation Loss_G: 0.6054
# [34/1000][0/2] Loss_D: 1.6142 Loss_G: 0.6718
# Validation Loss_D: 1.5809 	Validation Loss_G: 0.6076
# [35/1000][0/2] Loss_D: 1.6009 Loss_G: 0.6760
# Validation Loss_D: 1.6028 	Validation Loss_G: 0.5928
# [36/1000][0/2] Loss_D: 1.6069 Loss_G: 0.6640
# Validation Loss_D: 1.6200 	Validation Loss_G: 0.5739
# [37/1000][0/2] Loss_D: 1.6199 Loss_G: 0.6569
# Validation Loss_D: 1.6287 	Validation Loss_G: 0.5723
# [38/1000][0/2] Loss_D: 1.6112 Loss_G: 0.6656
# Validation Loss_D: 1.6200 	Validation Loss_G: 0.5852
# [39/1000][0/2] Loss_D: 1.5921 Loss_G: 0.6848
# Validation Loss_D: 1.6075 	Validation Loss_G: 0.5961
# [40/1000][0/2] Loss_D: 1.5755 Loss_G: 0.6975
# Validation Loss_D: 1.5979 	Validation Loss_G: 0.5997
# [41/1000][0/2] Loss_D: 1.5584 Loss_G: 0.7110
# Validation Loss_D: 1.5806 	Validation Loss_G: 0.6130
# [42/1000][0/2] Loss_D: 1.5315 Loss_G: 0.7307
# Validation Loss_D: 1.5629 	Validation Loss_G: 0.6330
# [43/1000][0/2] Loss_D: 1.5036 Loss_G: 0.7510
# Validation Loss_D: 1.5408 	Validation Loss_G: 0.6642
# [44/1000][0/2] Loss_D: 1.4777 Loss_G: 0.7642
# Validation Loss_D: 1.5334 	Validation Loss_G: 0.6673
# [45/1000][0/2] Loss_D: 1.4767 Loss_G: 0.7572
# Validation Loss_D: 1.5598 	Validation Loss_G: 0.6390
# [46/1000][0/2] Loss_D: 1.4909 Loss_G: 0.7395
# Validation Loss_D: 1.5877 	Validation Loss_G: 0.6182
# [47/1000][0/2] Loss_D: 1.5051 Loss_G: 0.7231
# Validation Loss_D: 1.6082 	Validation Loss_G: 0.5962
# [48/1000][0/2] Loss_D: 1.5257 Loss_G: 0.7056
# Validation Loss_D: 1.6227 	Validation Loss_G: 0.5929
# [49/1000][0/2] Loss_D: 1.5423 Loss_G: 0.6937
# Validation Loss_D: 1.6040 	Validation Loss_G: 0.6083
# [50/1000][0/2] Loss_D: 1.5380 Loss_G: 0.7027
# Validation Loss_D: 1.5806 	Validation Loss_G: 0.6280
# [51/1000][0/2] Loss_D: 1.5259 Loss_G: 0.7149
# Validation Loss_D: 1.5609 	Validation Loss_G: 0.6465
# [52/1000][0/2] Loss_D: 1.5083 Loss_G: 0.7279
# Validation Loss_D: 1.5325 	Validation Loss_G: 0.6682
# [53/1000][0/2] Loss_D: 1.4884 Loss_G: 0.7433
# Validation Loss_D: 1.5133 	Validation Loss_G: 0.6758
# [54/1000][0/2] Loss_D: 1.4759 Loss_G: 0.7466
# Validation Loss_D: 1.5091 	Validation Loss_G: 0.6769
# [55/1000][0/2] Loss_D: 1.4594 Loss_G: 0.7578
# Validation Loss_D: 1.4873 	Validation Loss_G: 0.6895
# [56/1000][0/2] Loss_D: 1.4348 Loss_G: 0.7790
# Validation Loss_D: 1.4725 	Validation Loss_G: 0.7063
# [57/1000][0/2] Loss_D: 1.4122 Loss_G: 0.7954
# Validation Loss_D: 1.4703 	Validation Loss_G: 0.6998
# [58/1000][0/2] Loss_D: 1.4036 Loss_G: 0.7965
# Validation Loss_D: 1.4752 	Validation Loss_G: 0.6880
# [59/1000][0/2] Loss_D: 1.4109 Loss_G: 0.7799
# Validation Loss_D: 1.4838 	Validation Loss_G: 0.6760
# [60/1000][0/2] Loss_D: 1.4131 Loss_G: 0.7779
# Validation Loss_D: 1.4728 	Validation Loss_G: 0.6873
# [61/1000][0/2] Loss_D: 1.4055 Loss_G: 0.7812
# Validation Loss_D: 1.4596 	Validation Loss_G: 0.6878
# [62/1000][0/2] Loss_D: 1.4031 Loss_G: 0.7787
# Validation Loss_D: 1.4664 	Validation Loss_G: 0.6710
# [63/1000][0/2] Loss_D: 1.4162 Loss_G: 0.7655
# Validation Loss_D: 1.4749 	Validation Loss_G: 0.6576
# [64/1000][0/2] Loss_D: 1.4361 Loss_G: 0.7474
# Validation Loss_D: 1.4787 	Validation Loss_G: 0.6507
# [65/1000][0/2] Loss_D: 1.4494 Loss_G: 0.7388
# Validation Loss_D: 1.4729 	Validation Loss_G: 0.6497
# [66/1000][0/2] Loss_D: 1.4438 Loss_G: 0.7445
# Validation Loss_D: 1.4585 	Validation Loss_G: 0.6629
# [67/1000][0/2] Loss_D: 1.4301 Loss_G: 0.7561
# Validation Loss_D: 1.4338 	Validation Loss_G: 0.6809
# [68/1000][0/2] Loss_D: 1.4074 Loss_G: 0.7708
# Validation Loss_D: 1.3987 	Validation Loss_G: 0.7037
# [69/1000][0/2] Loss_D: 1.3813 Loss_G: 0.7908
# Validation Loss_D: 1.3555 	Validation Loss_G: 0.7413
# [70/1000][0/2] Loss_D: 1.3602 Loss_G: 0.8055
# Validation Loss_D: 1.3244 	Validation Loss_G: 0.7716
# [71/1000][0/2] Loss_D: 1.3374 Loss_G: 0.8235
# Validation Loss_D: 1.3106 	Validation Loss_G: 0.7826
# [72/1000][0/2] Loss_D: 1.3210 Loss_G: 0.8312
# Validation Loss_D: 1.3044 	Validation Loss_G: 0.7772
# [73/1000][0/2] Loss_D: 1.3101 Loss_G: 0.8357
# Validation Loss_D: 1.2923 	Validation Loss_G: 0.7886
# [74/1000][0/2] Loss_D: 1.3009 Loss_G: 0.8363
# Validation Loss_D: 1.2986 	Validation Loss_G: 0.7693
# [75/1000][0/2] Loss_D: 1.3004 Loss_G: 0.8282
# Validation Loss_D: 1.3110 	Validation Loss_G: 0.7481
# [76/1000][0/2] Loss_D: 1.3098 Loss_G: 0.8149
# Validation Loss_D: 1.3231 	Validation Loss_G: 0.7387
# [77/1000][0/2] Loss_D: 1.3245 Loss_G: 0.7987
# Validation Loss_D: 1.3444 	Validation Loss_G: 0.7213
# [78/1000][0/2] Loss_D: 1.3414 Loss_G: 0.7859
# Validation Loss_D: 1.3548 	Validation Loss_G: 0.7145
# [79/1000][0/2] Loss_D: 1.3538 Loss_G: 0.7724
# Validation Loss_D: 1.3578 	Validation Loss_G: 0.7182
# [80/1000][0/2] Loss_D: 1.3543 Loss_G: 0.7757
# Validation Loss_D: 1.3555 	Validation Loss_G: 0.7281
# [81/1000][0/2] Loss_D: 1.3543 Loss_G: 0.7786
# Validation Loss_D: 1.3469 	Validation Loss_G: 0.7331
# [82/1000][0/2] Loss_D: 1.3482 Loss_G: 0.7868
# Validation Loss_D: 1.3227 	Validation Loss_G: 0.7595
# [83/1000][0/2] Loss_D: 1.3297 Loss_G: 0.8130
# Validation Loss_D: 1.3213 	Validation Loss_G: 0.7610
# [84/1000][0/2] Loss_D: 1.3244 Loss_G: 0.8163
# Validation Loss_D: 1.3349 	Validation Loss_G: 0.7516
# [85/1000][0/2] Loss_D: 1.3229 Loss_G: 0.8133
# Validation Loss_D: 1.3374 	Validation Loss_G: 0.7592
# [86/1000][0/2] Loss_D: 1.3088 Loss_G: 0.8265
# Validation Loss_D: 1.3347 	Validation Loss_G: 0.7639
# [87/1000][0/2] Loss_D: 1.2891 Loss_G: 0.8459
# Validation Loss_D: 1.3313 	Validation Loss_G: 0.7559
# [88/1000][0/2] Loss_D: 1.2803 Loss_G: 0.8456
# Validation Loss_D: 1.3332 	Validation Loss_G: 0.7527
# [89/1000][0/2] Loss_D: 1.2761 Loss_G: 0.8431
# Validation Loss_D: 1.3278 	Validation Loss_G: 0.7681
# [90/1000][0/2] Loss_D: 1.2712 Loss_G: 0.8461
# Validation Loss_D: 1.3350 	Validation Loss_G: 0.7552
# [91/1000][0/2] Loss_D: 1.2675 Loss_G: 0.8461
# Validation Loss_D: 1.3366 	Validation Loss_G: 0.7635
# [92/1000][0/2] Loss_D: 1.2687 Loss_G: 0.8434
# Validation Loss_D: 1.3323 	Validation Loss_G: 0.7717
# [93/1000][0/2] Loss_D: 1.2656 Loss_G: 0.8474
# Validation Loss_D: 1.3284 	Validation Loss_G: 0.7696
# [94/1000][0/2] Loss_D: 1.2600 Loss_G: 0.8480
# Validation Loss_D: 1.3215 	Validation Loss_G: 0.7811
# [95/1000][0/2] Loss_D: 1.2627 Loss_G: 0.8436
# Validation Loss_D: 1.3216 	Validation Loss_G: 0.7745
# [96/1000][0/2] Loss_D: 1.2729 Loss_G: 0.8309
# Validation Loss_D: 1.3308 	Validation Loss_G: 0.7641
# [97/1000][0/2] Loss_D: 1.2827 Loss_G: 0.8158
# Validation Loss_D: 1.3451 	Validation Loss_G: 0.7486
# [98/1000][0/2] Loss_D: 1.2780 Loss_G: 0.8214
# Validation Loss_D: 1.3371 	Validation Loss_G: 0.7583
# [99/1000][0/2] Loss_D: 1.2578 Loss_G: 0.8421
# Validation Loss_D: 1.3249 	Validation Loss_G: 0.7758
# [100/1000][0/2] Loss_D: 1.2324 Loss_G: 0.8673
# Validation Loss_D: 1.3177 	Validation Loss_G: 0.7900
# [101/1000][0/2] Loss_D: 1.2207 Loss_G: 0.8687
# Validation Loss_D: 1.3200 	Validation Loss_G: 0.7930
# [102/1000][0/2] Loss_D: 1.2269 Loss_G: 0.8619
# Validation Loss_D: 1.3330 	Validation Loss_G: 0.7791
# [103/1000][0/2] Loss_D: 1.2374 Loss_G: 0.8507
# Validation Loss_D: 1.3465 	Validation Loss_G: 0.7575
# [104/1000][0/2] Loss_D: 1.2489 Loss_G: 0.8359
# Validation Loss_D: 1.3531 	Validation Loss_G: 0.7639
# [105/1000][0/2] Loss_D: 1.2543 Loss_G: 0.8341
# Validation Loss_D: 1.3582 	Validation Loss_G: 0.7581
# [106/1000][0/2] Loss_D: 1.2576 Loss_G: 0.8353
# Validation Loss_D: 1.3594 	Validation Loss_G: 0.7644
# [107/1000][0/2] Loss_D: 1.2549 Loss_G: 0.8481
# Validation Loss_D: 1.3562 	Validation Loss_G: 0.7819
# [108/1000][0/2] Loss_D: 1.2496 Loss_G: 0.8532
# Validation Loss_D: 1.3472 	Validation Loss_G: 0.7959
# [109/1000][0/2] Loss_D: 1.2406 Loss_G: 0.8625
# Validation Loss_D: 1.3216 	Validation Loss_G: 0.8196
# [110/1000][0/2] Loss_D: 1.2214 Loss_G: 0.8863
# Validation Loss_D: 1.3005 	Validation Loss_G: 0.8353
# [111/1000][0/2] Loss_D: 1.1986 Loss_G: 0.9067
# Validation Loss_D: 1.2937 	Validation Loss_G: 0.8467
# [112/1000][0/2] Loss_D: 1.1730 Loss_G: 0.9333
# Validation Loss_D: 1.2931 	Validation Loss_G: 0.8432
# [113/1000][0/2] Loss_D: 1.1548 Loss_G: 0.9484
# Validation Loss_D: 1.3280 	Validation Loss_G: 0.7990
# [114/1000][0/2] Loss_D: 1.1580 Loss_G: 0.9331
# Validation Loss_D: 1.3618 	Validation Loss_G: 0.7743
# Early stopping na época 114!
# Modelo salvo em: ./models_saved/dcgan/3/40/fold5/generator.pth
# Iniciando o teste ....
# 0.7147894896401299 horas
